# %% [markdown]
# # Test set analysis

# %%
from import_man import *

# %%
df = pd.read_csv("dataset/test.csv")

# %%
df.shape
# Out:
# (45689, 34)

# %%
df.head().T
# Out:
#                                        0             1             2  \
# StoreID                             1000          1000          1000
# Date                          01/03/2018    02/03/2018    03/03/2018
# IsHoliday                              0             0             0
# IsOpen                                 1             1             1
# HasPromotions                          0             0             0
# StoreType                   Hyper Market  Hyper Market  Hyper Market
# AssortmentType                   General       General       General
# NearestCompetitor                    326           326           326
# Region                                 7             7             7
# Region_AreaKM2                      9643          9643          9643
# Region_GDP                         17130         17130         17130
# Region_PopulationK                  2770          2770          2770
# CloudCover                             6             7             2
# ...

# %% [markdown]
# ### How many days are the stores open?

# %%
df.loc[(df['IsOpen'] == 1)]
# Out:
#        StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 0         1000  01/03/2018          0       1              0  Hyper Market
# 1         1000  02/03/2018          0       1              0  Hyper Market
# 2         1000  03/03/2018          0       1              0  Hyper Market
# 4         1000  05/03/2018          0       1              1  Hyper Market
# 5         1000  06/03/2018          0       1              1  Hyper Market
# 6         1000  07/03/2018          0       1              1  Hyper Market
# 7         1000  08/03/2018          0       1              1  Hyper Market
# 8         1000  09/03/2018          0       1              1  Hyper Market
# 9         1000  10/03/2018          0       1              0  Hyper Market
# 11        1000  12/03/2018          0       1              0  Hyper Market
# 12        1000  13/03/2018          0       1              0  Hyper Market
# ...

# %% [markdown]
# ### Closed days percentage

# %%
((45689-37586)/45689)*100
# Out:
# 17.735122239488717
