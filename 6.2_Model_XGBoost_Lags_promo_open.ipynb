# %% [markdown]
# # XGBoost model

# %%
import pandas as pd
import numpy as np
#from sklearn import cross_validation
from sklearn.model_selection import cross_validate
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import validation_curve

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['figure.figsize'] = [20.0,8.0]
plt.rcParams['figure.dpi']=80

import modify_dataset as md

# %%
#Common error function to minimize: Root Mean Square Percentage Error
#We will have to integrate our loss function with xgboost

def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    return w


def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
    return rmspe


def rmspe_xg(yhat, y):
    # y = y.values
    y = y.get_label()
    y = np.exp(y) - 1
    yhat = np.exp(yhat) - 1
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat)**2))
    return "rmspe", rmspe

# %%
df = pd.read_csv("dataset/preprocessed_PCA_train.csv")

# %%
df = df.drop(['NumberOfCustomers'], axis=1)
#df = df.drop(['Region','Events'], axis=1)
# I could leave events

# %%
df = df[df.IsOpen == 1]

# %%
#for now let's drop unusable categorical vars
df = df.drop(['StoreType','AssortmentType','Events'], axis=1)

# %%
#only for PCA
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head(20).T
# Out:
#                                       0            1            2   \
# StoreID                             1000         1000         1000
# Date                          01/03/2016   02/03/2016   04/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5676         8111         8300
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             8            8            8
# Max_VisibilityKm                       0            1            2
# Min_VisibilitykM                       0            1            2
# WindDirDegrees                        23           56           22
# D_Day                                  1            2            4
# D_DayOfYear                           61           62           64
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            1            2            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                  0.62349    -0.222521    -0.900969
# D_DayOfWeek_sin                 0.781831     0.974928    -0.433884
# p1                             0.0038253   0.00380447   0.00215876
# p2                             0.0014332  0.000903979 -0.000101837
# p3                           -0.00076347 -0.000480038 -0.000370168
# p4                          -0.000912617 -0.000547427 -0.000560225
# p5                           -0.00222642  -0.00247007  0.000554448
# p6                            0.00224159   0.00230143  -0.00110596
# p7                          -0.000719875   0.00107936 -0.000526003
# p8                           -0.00116095  -0.00118984  -0.00130027
# p9                           0.000247264  4.99143e-05 -0.000166103
# p10                          -0.00013257  0.000141136 -0.000514758
# p11                         -0.000344916 -0.000293834 -0.000337692
# p12                          -4.3497e-05   0.00016746  0.000414398
#
#                                       3            5            6   \
# StoreID                             1000         1000         1000
# Date                          05/03/2016   07/03/2016   08/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       7154        10110         9019
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            0            0
# Max_VisibilityKm                       3            5            6
# Min_VisibilitykM                       3            5            6
# WindDirDegrees                       108           68           62
# D_Day                                  5            7            8
# D_DayOfYear                           65           67           68
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                            0.00293107   0.00261322   0.00236662
# p2                          -0.000539355 -0.000531053 -0.000662307
# p3                          -0.000204276 -0.000171205 -8.46579e-05
# p4                          -0.000257912  -0.00031086 -0.000191952
# p5                           0.000438362  0.000403522  0.000326159
# p6                           -0.00145466   -0.0013466  -0.00120862
# p7                            0.00139192   0.00129003   0.00148701
# p8                           -0.00117349  -0.00112774  -0.00124582
# p9                           0.000203075   0.00037153 -6.42772e-05
# p10                         -0.000551018  -0.00035296 -0.000653497
# p11                         -0.000326059  5.03901e-05 -4.39029e-05
# p12                           0.00025032  0.000291776  7.02017e-06
#
#                                       7            8            9   \
# StoreID                             1000         1000         1000
# Date                          09/03/2016   10/03/2016   11/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          1            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       8804         7823         7989
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            7            7
# Max_VisibilityKm                       7            8            9
# Min_VisibilitykM                       7            8            9
# WindDirDegrees                        53           54           30
# D_Day                                  9           10           11
# D_DayOfYear                           69           70           71
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884    -0.433884
# p1                            0.00185775  0.000473164 -0.000416869
# p2                           -0.00067526 -0.000457064 -0.000287349
# p3                          -2.25402e-05 -1.45983e-05 -1.82241e-05
# p4                          -0.000306754 -0.000647226 -0.000792144
# p5                           0.000255091  0.000167626   0.00023278
# p6                           -0.00103422 -0.000539841 -0.000105736
# p7                            0.00139519 -2.56231e-05 -0.000303005
# p8                           -0.00119338  -0.00132962  -0.00128861
# p9                           0.000124802 -0.000294708 -0.000151588
# p10                         -0.000468897  -0.00137889 -0.000605416
# p11                          7.81451e-05 -0.000204166 -0.000212506
# p12                          -0.00010592 -4.79889e-05 -0.000167507
#
#                                       10           12           13  \
# StoreID                             1000         1000         1000
# Date                          12/03/2016   14/03/2016   15/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5895         6348         4738
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            7            7
# Max_VisibilityKm                      10           12           13
# Min_VisibilitykM                      10           12           13
# WindDirDegrees                       202           26           26
# D_Day                                 12           14           15
# D_DayOfYear                           72           74           75
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                           -0.00021493   0.00454891   0.00485476
# p2                          -0.000300094   0.00152879   0.00280597
# p3                          -1.93295e-05 -0.000878183  -0.00144622
# p4                          -0.000840343 -0.000915415   0.00177991
# p5                           0.000170166  -0.00210205 -0.000269195
# p6                            -0.0002203   0.00188936   0.00290054
# p7                          -0.000694627 -0.000661546 -0.000843696
# p8                           -0.00124548  -0.00105218 -0.000794234
# p9                           2.26767e-05  0.000650834   0.00161685
# p10                         -0.000104071 -0.000373564  2.09806e-05
# p11                          0.000304696 -0.000103976 -0.000567888
# p12                          0.000120549  -8.6487e-05 -0.000151292
#
#                                       14           15           16  \
# StoreID                             1000         1000         1000
# Date                          16/03/2016   17/03/2016   18/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6014         6087         6962
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             5            4            2
# Max_VisibilityKm                      14           15           16
# Min_VisibilitykM                      14           15           16
# WindDirDegrees                        27          272          218
# D_Day                                 16           17           18
# D_DayOfYear                           76           77           78
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884    -0.433884
# p1                            0.00590618   0.00619993   0.00620682
# p2                            0.00112061    0.0012244   0.00106947
# p3                           -0.00079585 -0.000888527 -0.000800649
# p4                          -0.000396647 -6.89417e-06 -0.000271905
# p5                           -0.00211805   -0.0019094  -0.00210155
# p6                            0.00141545   0.00145775   0.00128724
# p7                            0.00123804   0.00139421   0.00146344
# p8                           -0.00107538  -0.00124269  -0.00111452
# p9                           0.000479975 -0.000106806  0.000340916
# p10                         -0.000359549 -0.000654383 -0.000817936
# p11                         -0.000204156  0.000866687 -1.55093e-05
# p12                           0.00014157 -9.86859e-05   6.9519e-05
#
#                                       17           19           20  \
# StoreID                             1000         1000         1000
# Date                          19/03/2016   21/03/2016   22/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6618         9183         8155
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            6            4
# Max_VisibilityKm                      17           19           20
# Min_VisibilitykM                      17           19           20
# WindDirDegrees                       138          190          211
# D_Day                                 19           21           22
# D_DayOfYear                           79           81           82
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                            0.00389524   0.00180157   0.00183232
# p2                           -0.00052353  -0.00104194 -0.000465838
# p3                          -0.000309571  0.000374328  7.00345e-05
# p4                          -0.000147691   0.00211691   0.00174133
# p5                           0.000539229  0.000427248   0.00068135
# p6                           -0.00190977 -0.000453241 -0.000564274
# p7                            0.00175458  0.000625665  -0.00123484
# p8                           -0.00113884  -0.00102667 -0.000933344
# p9                           0.000335526  0.000759144   0.00120153
# p10                           -0.0013901 -0.000305311 -0.000471439
# p11                         -0.000301076 -0.000162035  0.000449306
# p12                          0.000542752 -0.000404629  0.000203928
#
#                                       21           22
# StoreID                             1000         1000
# Date                          23/03/2016   24/03/2016
# IsHoliday                              0            0
# IsOpen                                 1            1
# HasPromotions                          1            1
# NearestCompetitor                    326          326
# Region                                 7            7
# NumberOfSales                       7109         8041
# Region_AreaKM2                      9643         9643
# Region_GDP                         17130        17130
# Region_PopulationK                  2770         2770
# CloudCover                             6            6
# Max_VisibilityKm                      21           22
# Min_VisibilitykM                      21           22
# WindDirDegrees                       191          331
# D_Day                                 23           24
# D_DayOfYear                           83           84
# D_Month                                3            3
# D_Year                              2016         2016
# D_DayOfweek                            2            3
# StoreType_SuperMarket                  0            0
# StoreType_HyperMarket                  1            1
# StoreType_StandardMarket               0            0
# StoreType_ShoppingCenter               0            0
# AssortmentType_General                 1            1
# AssortmentType_WithNFDept              0            0
# AssortmentType_WithFishDept            0            0
# MeanStoreSales                   6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884
# p1                             0.0010165   0.00392148
# p2                            0.00139047   0.00132576
# p3                           -0.00109489 -0.000718271
# p4                          -0.000321022 -0.000839272
# p5                            0.00196911  -0.00228311
# p6                          -9.33638e-05   0.00213789
# p7                           9.40244e-06 -0.000332149
# p8                           -0.00122761  -0.00117337
# p9                           0.000106001  0.000198016
# p10                         -0.000386896 -0.000910045
# p11                          0.000579355 -0.000281794
# p12                          0.000234422  0.000193493

# %%
df.shape
# Out:
# (433958, 43)

# %%
train = md.get_fake_train(df)

# %%
train.shape
# Out:
# (397047, 43)

# %%
test = md.get_fake_test(df)
test.shape
# Out:
# (36911, 43)

# %%
#print("Load the training, test and store data using pandas")
#train = pd.read_csv("train.csv",low_memory=False)
#test = pd.read_csv("test.csv")
#store = pd.read_csv("store.csv")

# %% [markdown]
# ### Selecting predictive features

# %%
features = list(train.columns.values)
features.remove('NumberOfSales')
features.remove('StoreID')
features.remove('Date')
features.remove('IsOpen')
#features.remove('IsOpen_t-7')
#features.remove('IsOpen_t-4')  #Is Open lags worsen a lot
#features.remove('IsOpen_t-1')
#features.remove('HasPromotions_t-2')
#features.remove('HasPromotions_t-1')
#features.remove('Region_GDP')
#features.remove('Max_Dew_PointC')
#features.remove('Min_Dew_PointC')
#features.remove('Max_Wind_SpeedKm_h')
#features.remove('Max_VisibilityKm')
#features.remove('IsOpen')
#features.remove('Min_Sea_Level_PressurehPa')
#features.remove('Precipitationmm')
#features.remove('Mean_Dew_PointC')
#features.remove('Min_TemperatureC')
print("features")

print(features)
# Out:
# features
# ['IsHoliday', 'HasPromotions', 'NearestCompetitor', 'Region', 'Region_AreaKM2', 'Region_GDP', 'Region_PopulationK', 'CloudCover', 'Max_VisibilityKm', 'Min_VisibilitykM', 'WindDirDegrees', 'D_Day', 'D_DayOfYear', 'D_Month', 'D_Year', 'D_DayOfweek', 'StoreType_SuperMarket', 'StoreType_HyperMarket', 'StoreType_StandardMarket', 'StoreType_ShoppingCenter', 'AssortmentType_General', 'AssortmentType_WithNFDept', 'AssortmentType_WithFishDept', 'MeanStoreSales', 'MeanRegionSales', 'D_DayOfWeek_cos', 'D_DayOfWeek_sin', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12']

# %% [markdown]
# features.remove('p6')
# features.remove('p3')
# features.remove('p7')
# features.remove('p9')
# features.remove('Events_Thunderstorm')
# features.remove('Events_Fog')

# %% [markdown]
# params = {"objective": "reg:linear",
#           "eta": 0.2,
#           "max_depth": 8,
#           "subsample": 1.0,
#           "colsample_bytree": 0.3, #0.3
#           "silent": 1,
#           "nthread":-1,
#           #added as a test
#           #"eval_metric": "rmse",
#           #"gamma": 2  #added as a test
#           }
#
# #reg_alpha
# #reg_lambda
# num_trees = 400 #400

# %%
#split in train and test (not real test which is called test and is the fake test provided by md)
X_train, X_test = train_test_split(train, test_size=0.05)
#X_train, X_test = train.head(len(train) - val_size), train.tail(val_size)

# %%
dtrain = xgb.DMatrix(X_train[features], np.log(X_train["NumberOfSales"] + 1))
dvalid = xgb.DMatrix(X_test[features], np.log(X_test["NumberOfSales"] + 1))
#dtest = xgb.DMatrix(test[features])

# %%
X_train.shape
# Out:
# (377194, 43)

# %%
X_test.shape
# Out:
# (19853, 43)

# %%
watchlist = [(dvalid, 'test'), (dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, feval=rmspe_xg, verbose_eval=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-a2936e6ca2c9> in <module>()
#       1 watchlist = [(dvalid, 'test'), (dtrain, 'train')]
# ----> 2 gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, feval=rmspe_xg, verbose_eval=True)
#
# NameError: name 'params' is not defined

# %%
#watchlist = [(dvalid, 'test'), (dtrain, 'train')]
#gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, verbose_eval=True)

# %% [markdown]
# ### Validating

# %%
print("Validating")
train_probs = gbm.predict(xgb.DMatrix(X_test[features]))
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)

# %% [markdown]
# RMSE

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="gain")
plt.title("XGBoost Feature Gain")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="weight")
plt.title("XGBoost Feature weight")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="cover")
plt.title("XGBoost Feature cover")
plt.show()

# %% [markdown]
# ### Predict on fake test set

# %%
train_probs = gbm.predict(xgb.DMatrix(test[features]))

# %%
test['_NumberOfSales'] = np.exp(gbm.predict(xgb.DMatrix(test[features])))-1

# %% [markdown]
# ## BIP Error

# %%
from BIP import get_BIP_error
error1 = get_BIP_error(test)

# %%
diff=test['NumberOfSales']-test['_NumberOfSales']

# %%
diff.head(15).T

# %%
diff.mean()

# %%
train_probs.shape

# %%
#test['predicted'] = pd.Series([train_probs], index=test.index)
#test['predicted']=train_probs

# %%
compare = test[['NumberOfSales','_NumberOfSales']]

# %% [markdown]
# ### Saving TEST

# %%
#test.to_csv('./dataset/XGB5_fake_test.csv', index=False)

# %%
error = rmspe(test['_NumberOfSales'].values, test['NumberOfSales'].values)
print('error', error)

# %%
compare[1000:1100]

# %%
compare[1000:1100]

# %%
#REAL
start = 500
end = 600
import matplotlib.pyplot as plt

y = compare.iloc[start:end,0].values
x_coordinate = [ 1 * i for i in range(len(y)) ]
plt.plot(x_coordinate,y)
plt.show()

# %%
import matplotlib.pyplot as plt

yhat = compare.iloc[start:end:1].values
x_coordinate = [ 1 * i for i in range(len(yhat)) ]
plt.plot(x_coordinate,yhat)
plt.legend(['Real', 'Predicted'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
#import matplotlib as mpl

#mpl.style.use("default")


plt.plot(x_coordinate,y)
plt.plot(x_coordinate,yhat)
plt.legend(['Predicted', 'Real'], loc='upper left')
plt.show()

# %%
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)

# %%
test_probs = gbm.predict(xgb.DMatrix(test[features]))
indices = test_probs < 0
test_probs[indices] = 0
submission = pd.DataFrame({"Id": test["Id"], "Sales": np.exp(test_probs) - 1})
submission.to_csv("xgboost_kscript_submission.csv", index=False)

# %%
Y = df.iloc[:, 3]

# %%
Y
