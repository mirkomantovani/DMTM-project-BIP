# %% [markdown]
# # Data exploration - Correlation
#
# Analysis of the attributes correlation.

# %%
from dataset_features import numerical, categorical

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":20,"axes.titlesize":30,"axes.labelsize":30})  

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./dataset/train.csv')

# Use only numerical attributes
df = df[numerical]
df.head()
# Out:
#    Mean_TemperatureC  Min_TemperatureC  Mean_Humidity  NearestCompetitor  \
# 0                  1                 1             82                326
# 1                  3                 1             73                326
# 2                  3                 2             71                326
# 3                  3                -1             56                326
# 4                  1                -5             75                326
#
#    Mean_VisibilityKm  Mean_Sea_Level_PressurehPa  Mean_Wind_SpeedKm_h  \
# 0               11.0                        1030                   16
# 1               13.0                        1027                   10
# 2               11.0                        1024                   10
# 3               15.0                        1024                   10
# 4               12.0                        1023                    5
#
#    Region_AreaKM2  Precipitationmm  Max_Wind_SpeedKm_h        ...         \
# 0            9643              0.0                  21        ...
# 1            9643              0.0                  16        ...
# 2            9643              0.0                  23        ...
# 3            9643              0.0                  19        ...
# 4            9643              0.0                  16        ...
#
#    Max_Dew_PointC  CloudCover  NumberOfSales  Region_PopulationK  \
# 0               1         8.0           5676                2770
# 1               0         8.0           8111                2770
# 2               0         8.0           8300                2770
# 3              -3         6.0           7154                2770
# 4               0         6.0              0                2770
#
#    WindDirDegrees  Min_Dew_PointC  Region_GDP  Max_Humidity  Min_Humidity  \
# 0              23              -2       17130           100            70
# 1              56              -2       17130            87            58
# 2              22              -3       17130            81            55
# 3             108              -6       17130            80            25
# 4              46              -6       17130            93            48
#
#    Max_TemperatureC
# 0                 2
# 1                 5
# 2                 4
# 3                 8
# 4                 7
#
# [5 rows x 27 columns]

# %%
covariance=df.corr(method='pearson')

# %%
plt.rcParams['figure.figsize'] = [50.0,50.0]
plt.rcParams['figure.dpi']=70

sns.set(font_scale=4)
sns.heatmap(covariance,square=True, cmap="Oranges")

# %%
plt.rcParams['figure.figsize'] = [50.0,50.0]
plt.rcParams['figure.dpi']=80

sns.set(font_scale=2)
sns.heatmap(covariance, square=True, annot=True, cmap="Oranges", xticklabels=False,  yticklabels=False)
