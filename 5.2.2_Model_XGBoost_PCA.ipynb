# %% [markdown]
# # XGBoost model

# %%
import pandas as pd
import numpy as np
#from sklearn import cross_validation
from sklearn.model_selection import cross_validate
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import validation_curve

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['figure.figsize'] = [20.0,8.0]
plt.rcParams['figure.dpi']=80

import modify_dataset as md

# %%
#Common error function to minimize: Root Mean Square Percentage Error
#We will have to integrate our loss function with xgboost

def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    return w


def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
    return rmspe


def rmspe_xg(yhat, y):
    # y = y.values
    y = y.get_label()
    y = np.exp(y) - 1
    yhat = np.exp(yhat) - 1
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat)**2))
    return "rmspe", rmspe

# %%
df = pd.read_csv("dataset/preprocessed_train_PCA.csv")

# %%
df = df.drop(['NumberOfCustomers'], axis=1)
#df = df.drop(['Region','Events'], axis=1)
# I could leave events

# %%
df = df[df.IsOpen == 1]

# %%
#for now let's drop unusable categorical vars
df = df.drop(['StoreType','AssortmentType','Events'], axis=1)

# %%
#only for pca
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head(20).T
# Out:
#                                       0            1            2   \
# StoreID                             1000         1000         1000
# Date                          01/03/2016   02/03/2016   04/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5676         8111         8300
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             8            8            8
# Max_VisibilityKm                       0            1            2
# Min_VisibilitykM                       0            1            2
# WindDirDegrees                        23           56           22
# D_Day                                  1            2            4
# D_DayOfYear                           61           62           64
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            1            2            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                  0.62349    -0.222521    -0.900969
# D_DayOfWeek_sin                 0.781831     0.974928    -0.433884
# p1                             0.0038253   0.00380447   0.00215876
# p2                             0.0014332  0.000903979 -0.000101837
# p3                           -0.00076347 -0.000480038 -0.000370168
# p4                          -0.000912617 -0.000547427 -0.000560225
# p5                           -0.00222642  -0.00247007  0.000554448
# p6                            0.00224159   0.00230143  -0.00110596
# p7                          -0.000719875   0.00107936 -0.000526003
# p8                           -0.00116095  -0.00118984  -0.00130027
# p9                           0.000247264  4.99143e-05 -0.000166103
# p10                          -0.00013257  0.000141136 -0.000514758
# p11                         -0.000344916 -0.000293834 -0.000337692
# p12                          -4.3497e-05   0.00016746  0.000414398
#
#                                       3            5            6   \
# StoreID                             1000         1000         1000
# Date                          05/03/2016   07/03/2016   08/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       7154        10110         9019
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            0            0
# Max_VisibilityKm                       3            5            6
# Min_VisibilitykM                       3            5            6
# WindDirDegrees                       108           68           62
# D_Day                                  5            7            8
# D_DayOfYear                           65           67           68
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                            0.00293107   0.00261322   0.00236662
# p2                          -0.000539355 -0.000531053 -0.000662307
# p3                          -0.000204276 -0.000171205 -8.46579e-05
# p4                          -0.000257912  -0.00031086 -0.000191952
# p5                           0.000438362  0.000403522  0.000326159
# p6                           -0.00145466   -0.0013466  -0.00120862
# p7                            0.00139192   0.00129003   0.00148701
# p8                           -0.00117349  -0.00112774  -0.00124582
# p9                           0.000203075   0.00037153 -6.42772e-05
# p10                         -0.000551018  -0.00035296 -0.000653497
# p11                         -0.000326059  5.03901e-05 -4.39029e-05
# p12                           0.00025032  0.000291776  7.02017e-06
#
#                                       7            8            9   \
# StoreID                             1000         1000         1000
# Date                          09/03/2016   10/03/2016   11/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          1            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       8804         7823         7989
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            7            7
# Max_VisibilityKm                       7            8            9
# Min_VisibilitykM                       7            8            9
# WindDirDegrees                        53           54           30
# D_Day                                  9           10           11
# D_DayOfYear                           69           70           71
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884    -0.433884
# p1                            0.00185775  0.000473164 -0.000416869
# p2                           -0.00067526 -0.000457064 -0.000287349
# p3                          -2.25402e-05 -1.45983e-05 -1.82241e-05
# p4                          -0.000306754 -0.000647226 -0.000792144
# p5                           0.000255091  0.000167626   0.00023278
# p6                           -0.00103422 -0.000539841 -0.000105736
# p7                            0.00139519 -2.56231e-05 -0.000303005
# p8                           -0.00119338  -0.00132962  -0.00128861
# p9                           0.000124802 -0.000294708 -0.000151588
# p10                         -0.000468897  -0.00137889 -0.000605416
# p11                          7.81451e-05 -0.000204166 -0.000212506
# p12                          -0.00010592 -4.79889e-05 -0.000167507
#
#                                       10           12           13  \
# StoreID                             1000         1000         1000
# Date                          12/03/2016   14/03/2016   15/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5895         6348         4738
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            7            7
# Max_VisibilityKm                      10           12           13
# Min_VisibilitykM                      10           12           13
# WindDirDegrees                       202           26           26
# D_Day                                 12           14           15
# D_DayOfYear                           72           74           75
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                           -0.00021493   0.00454891   0.00485476
# p2                          -0.000300094   0.00152879   0.00280597
# p3                          -1.93295e-05 -0.000878183  -0.00144622
# p4                          -0.000840343 -0.000915415   0.00177991
# p5                           0.000170166  -0.00210205 -0.000269195
# p6                            -0.0002203   0.00188936   0.00290054
# p7                          -0.000694627 -0.000661546 -0.000843696
# p8                           -0.00124548  -0.00105218 -0.000794234
# p9                           2.26767e-05  0.000650834   0.00161685
# p10                         -0.000104071 -0.000373564  2.09806e-05
# p11                          0.000304696 -0.000103976 -0.000567888
# p12                          0.000120549  -8.6487e-05 -0.000151292
#
#                                       14           15           16  \
# StoreID                             1000         1000         1000
# Date                          16/03/2016   17/03/2016   18/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6014         6087         6962
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             5            4            2
# Max_VisibilityKm                      14           15           16
# Min_VisibilitykM                      14           15           16
# WindDirDegrees                        27          272          218
# D_Day                                 16           17           18
# D_DayOfYear                           76           77           78
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884    -0.433884
# p1                            0.00590618   0.00619993   0.00620682
# p2                            0.00112061    0.0012244   0.00106947
# p3                           -0.00079585 -0.000888527 -0.000800649
# p4                          -0.000396647 -6.89417e-06 -0.000271905
# p5                           -0.00211805   -0.0019094  -0.00210155
# p6                            0.00141545   0.00145775   0.00128724
# p7                            0.00123804   0.00139421   0.00146344
# p8                           -0.00107538  -0.00124269  -0.00111452
# p9                           0.000479975 -0.000106806  0.000340916
# p10                         -0.000359549 -0.000654383 -0.000817936
# p11                         -0.000204156  0.000866687 -1.55093e-05
# p12                           0.00014157 -9.86859e-05   6.9519e-05
#
#                                       17           19           20  \
# StoreID                             1000         1000         1000
# Date                          19/03/2016   21/03/2016   22/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6618         9183         8155
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            6            4
# Max_VisibilityKm                      17           19           20
# Min_VisibilitykM                      17           19           20
# WindDirDegrees                       138          190          211
# D_Day                                 19           21           22
# D_DayOfYear                           79           81           82
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                            0.00389524   0.00180157   0.00183232
# p2                           -0.00052353  -0.00104194 -0.000465838
# p3                          -0.000309571  0.000374328  7.00345e-05
# p4                          -0.000147691   0.00211691   0.00174133
# p5                           0.000539229  0.000427248   0.00068135
# p6                           -0.00190977 -0.000453241 -0.000564274
# p7                            0.00175458  0.000625665  -0.00123484
# p8                           -0.00113884  -0.00102667 -0.000933344
# p9                           0.000335526  0.000759144   0.00120153
# p10                           -0.0013901 -0.000305311 -0.000471439
# p11                         -0.000301076 -0.000162035  0.000449306
# p12                          0.000542752 -0.000404629  0.000203928
#
#                                       21           22
# StoreID                             1000         1000
# Date                          23/03/2016   24/03/2016
# IsHoliday                              0            0
# IsOpen                                 1            1
# HasPromotions                          1            1
# NearestCompetitor                    326          326
# Region                                 7            7
# NumberOfSales                       7109         8041
# Region_AreaKM2                      9643         9643
# Region_GDP                         17130        17130
# Region_PopulationK                  2770         2770
# CloudCover                             6            6
# Max_VisibilityKm                      21           22
# Min_VisibilitykM                      21           22
# WindDirDegrees                       191          331
# D_Day                                 23           24
# D_DayOfYear                           83           84
# D_Month                                3            3
# D_Year                              2016         2016
# D_DayOfweek                            2            3
# StoreType_SuperMarket                  0            0
# StoreType_HyperMarket                  1            1
# StoreType_StandardMarket               0            0
# StoreType_ShoppingCenter               0            0
# AssortmentType_General                 1            1
# AssortmentType_WithNFDept              0            0
# AssortmentType_WithFishDept            0            0
# MeanStoreSales                   6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884
# p1                             0.0010165   0.00392148
# p2                            0.00139047   0.00132576
# p3                           -0.00109489 -0.000718271
# p4                          -0.000321022 -0.000839272
# p5                            0.00196911  -0.00228311
# p6                          -9.33638e-05   0.00213789
# p7                           9.40244e-06 -0.000332149
# p8                           -0.00122761  -0.00117337
# p9                           0.000106001  0.000198016
# p10                         -0.000386896 -0.000910045
# p11                          0.000579355 -0.000281794
# p12                          0.000234422  0.000193493

# %%
df.shape
# Out:
# (433958, 43)

# %%
train = md.get_fake_train(df)

# %%
train.shape
# Out:
# (397047, 43)

# %%
test = md.get_fake_test(df)
test.shape
# Out:
# (36911, 43)

# %%
#print("Load the training, test and store data using pandas")
#train = pd.read_csv("train.csv",low_memory=False)
#test = pd.read_csv("test.csv")
#store = pd.read_csv("store.csv")

# %% [markdown]
# ### Selecting predictive features

# %%
from pprint import pprint
features = list(train.columns.values)
features.remove('NumberOfSales')
features.remove('StoreID')
features.remove('IsOpen')
#features.remove('Region')
#features.remove('Region_GDP')
#features.remove('Max_Dew_PointC')
#features.remove('Min_Sea_Level_PressurehPa')
#features.remove('Precipitationmm')
#features.remove('Mean_Dew_PointC')
#features.remove('Min_TemperatureC')
#features.remove('p11')
#features.remove('p4')
features.remove('D_DayOfweek')
features.remove('Date')
print("features")

pprint(features)
# Out:
# features
# ['IsHoliday',
#  'HasPromotions',
#  'NearestCompetitor',
#  'Region',
#  'Region_AreaKM2',
#  'Region_GDP',
#  'Region_PopulationK',
#  'CloudCover',
#  'Max_VisibilityKm',
#  'Min_VisibilitykM',
#  'WindDirDegrees',
#  'D_Day',
#  'D_DayOfYear',
#  'D_Month',
#  'D_Year',
#  'StoreType_SuperMarket',
#  'StoreType_HyperMarket',
#  'StoreType_StandardMarket',
#  'StoreType_ShoppingCenter',
#  'AssortmentType_General',
#  'AssortmentType_WithNFDept',
#  'AssortmentType_WithFishDept',
#  'MeanStoreSales',
#  'MeanRegionSales',
#  'D_DayOfWeek_cos',
#  'D_DayOfWeek_sin',
#  'p1',
#  'p2',
#  'p3',
#  'p4',
#  'p5',
#  'p6',
#  'p7',
#  'p8',
#  'p9',
#  'p10',
#  'p11',
#  'p12']

# %%
features.remove('p11')
features.remove('p12')
features.remove('p7')
features.remove('p9')

# %%
params = {"objective": "reg:linear",
          "eta": 0.2,
          "max_depth": 8,
          "subsample": 1.0,
          "colsample_bytree": 0.3, #0.3
          "silent": 1,
          "nthread":-1,
          #added as a test
          "eval_metric": "rmse",
          #"gamma": 2  #added as a test
          }

#reg_alpha 
#reg_lambda
num_trees = 200 #400

# %%
#split in train and test (not real test which is called test and is the fake test provided by md)
X_train, X_test = train_test_split(train, test_size=0.05)
#X_train, X_test = train.head(len(train) - val_size), train.tail(val_size)

# %%
dtrain = xgb.DMatrix(X_train[features], np.log(X_train["NumberOfSales"] + 1))
dvalid = xgb.DMatrix(X_test[features], np.log(X_test["NumberOfSales"] + 1))
#dtest = xgb.DMatrix(test[features])

# %%
X_train.shape
# Out:
# (377194, 43)

# %%
X_test.shape
# Out:
# (19853, 43)

# %%
#watchlist = [(dvalid, 'test'), (dtrain, 'train')]
#gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, feval=rmspe_xg, verbose_eval=True)

# %%
watchlist = [(dvalid, 'test'), (dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, verbose_eval=True)
# Out:
# [0]	test-rmse:6.34014	train-rmse:6.33708
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 20 rounds.
# [1]	test-rmse:5.07472	train-rmse:5.07234
# [2]	test-rmse:4.06543	train-rmse:4.06325
# [3]	test-rmse:3.25892	train-rmse:3.25683
# [4]	test-rmse:2.61026	train-rmse:2.60874
# [5]	test-rmse:2.09622	train-rmse:2.09466
# [6]	test-rmse:1.68121	train-rmse:1.68016
# [7]	test-rmse:1.35112	train-rmse:1.35055
# [8]	test-rmse:1.09012	train-rmse:1.0896
# [9]	test-rmse:0.882212	train-rmse:0.881894
# [10]	test-rmse:0.717673	train-rmse:0.71775
# [11]	test-rmse:0.586079	train-rmse:0.586662
# [12]	test-rmse:0.484163	train-rmse:0.484974
# [13]	test-rmse:0.404028	train-rmse:0.404975
# [14]	test-rmse:0.342391	train-rmse:0.343457
# [15]	test-rmse:0.29361	train-rmse:0.2951
# [16]	test-rmse:0.255241	train-rmse:0.256908
# [17]	test-rmse:0.229976	train-rmse:0.231945
# [18]	test-rmse:0.210304	train-rmse:0.212495
# [19]	test-rmse:0.193082	train-rmse:0.195573
# [20]	test-rmse:0.183053	train-rmse:0.185499
# [21]	test-rmse:0.173418	train-rmse:0.17605
# [22]	test-rmse:0.16839	train-rmse:0.170951
# [23]	test-rmse:0.16495	train-rmse:0.167364
# [24]	test-rmse:0.161335	train-rmse:0.163388
# [25]	test-rmse:0.159342	train-rmse:0.16131
# [26]	test-rmse:0.157361	train-rmse:0.159307
# [27]	test-rmse:0.154449	train-rmse:0.156315
# [28]	test-rmse:0.150888	train-rmse:0.152996
# [29]	test-rmse:0.150013	train-rmse:0.151761
# [30]	test-rmse:0.149396	train-rmse:0.15077
# [31]	test-rmse:0.148167	train-rmse:0.149265
# [32]	test-rmse:0.147272	train-rmse:0.148192
# [33]	test-rmse:0.146696	train-rmse:0.147299
# [34]	test-rmse:0.145397	train-rmse:0.145809
# [35]	test-rmse:0.143001	train-rmse:0.143495
# [36]	test-rmse:0.142366	train-rmse:0.142778
# [37]	test-rmse:0.142088	train-rmse:0.142393
# [38]	test-rmse:0.141534	train-rmse:0.141436
# [39]	test-rmse:0.140287	train-rmse:0.140232
# [40]	test-rmse:0.139077	train-rmse:0.139037
# [41]	test-rmse:0.138677	train-rmse:0.138529
# [42]	test-rmse:0.13838	train-rmse:0.138147
# [43]	test-rmse:0.137576	train-rmse:0.137207
# [44]	test-rmse:0.137381	train-rmse:0.136752
# [45]	test-rmse:0.136753	train-rmse:0.13524
# [46]	test-rmse:0.135838	train-rmse:0.134251
# [47]	test-rmse:0.135492	train-rmse:0.133886
# [48]	test-rmse:0.135272	train-rmse:0.133596
# [49]	test-rmse:0.135087	train-rmse:0.133068
# [50]	test-rmse:0.134352	train-rmse:0.132009
# [51]	test-rmse:0.134048	train-rmse:0.131509
# [52]	test-rmse:0.133955	train-rmse:0.131382
# [53]	test-rmse:0.133704	train-rmse:0.130963
# [54]	test-rmse:0.133492	train-rmse:0.130648
# [55]	test-rmse:0.132624	train-rmse:0.129442
# [56]	test-rmse:0.132273	train-rmse:0.128987
# [57]	test-rmse:0.131899	train-rmse:0.128532
# [58]	test-rmse:0.131765	train-rmse:0.12822
# [59]	test-rmse:0.131504	train-rmse:0.127574
# [60]	test-rmse:0.131468	train-rmse:0.127511
# [61]	test-rmse:0.13121	train-rmse:0.127163
# [62]	test-rmse:0.13075	train-rmse:0.126458
# [63]	test-rmse:0.130707	train-rmse:0.126286
# [64]	test-rmse:0.130302	train-rmse:0.125442
# [65]	test-rmse:0.130092	train-rmse:0.124966
# [66]	test-rmse:0.129816	train-rmse:0.12455
# [67]	test-rmse:0.12974	train-rmse:0.124493
# [68]	test-rmse:0.129554	train-rmse:0.124245
# [69]	test-rmse:0.129579	train-rmse:0.123914
# [70]	test-rmse:0.12934	train-rmse:0.123533
# [71]	test-rmse:0.129212	train-rmse:0.123284
# [72]	test-rmse:0.128941	train-rmse:0.122857
# [73]	test-rmse:0.128816	train-rmse:0.122613
# [74]	test-rmse:0.128797	train-rmse:0.122491
# [75]	test-rmse:0.128687	train-rmse:0.122165
# [76]	test-rmse:0.128406	train-rmse:0.121741
# [77]	test-rmse:0.128239	train-rmse:0.121488
# [78]	test-rmse:0.128105	train-rmse:0.120874
# [79]	test-rmse:0.1281	train-rmse:0.120852
# [80]	test-rmse:0.128025	train-rmse:0.120687
# [81]	test-rmse:0.127993	train-rmse:0.120614
# [82]	test-rmse:0.127797	train-rmse:0.120105
# [83]	test-rmse:0.127521	train-rmse:0.119515
# [84]	test-rmse:0.127419	train-rmse:0.119261
# [85]	test-rmse:0.127302	train-rmse:0.119068
# [86]	test-rmse:0.127174	train-rmse:0.118901
# [87]	test-rmse:0.127056	train-rmse:0.118387
# [88]	test-rmse:0.126758	train-rmse:0.117422
# [89]	test-rmse:0.126725	train-rmse:0.117203
# [90]	test-rmse:0.126614	train-rmse:0.116915
# [91]	test-rmse:0.126508	train-rmse:0.116549
# [92]	test-rmse:0.126468	train-rmse:0.116494
# [93]	test-rmse:0.126356	train-rmse:0.11635
# [94]	test-rmse:0.126328	train-rmse:0.116183
# [95]	test-rmse:0.126307	train-rmse:0.116027
# [96]	test-rmse:0.126294	train-rmse:0.115989
# [97]	test-rmse:0.126231	train-rmse:0.115871
# [98]	test-rmse:0.126116	train-rmse:0.115675
# [99]	test-rmse:0.125868	train-rmse:0.115432
# [100]	test-rmse:0.125747	train-rmse:0.115058
# [101]	test-rmse:0.125664	train-rmse:0.114763
# [102]	test-rmse:0.125598	train-rmse:0.114468
# [103]	test-rmse:0.125552	train-rmse:0.114167
# [104]	test-rmse:0.125499	train-rmse:0.114023
# [105]	test-rmse:0.125296	train-rmse:0.113464
# [106]	test-rmse:0.124986	train-rmse:0.113061
# [107]	test-rmse:0.124692	train-rmse:0.112705
# [108]	test-rmse:0.124652	train-rmse:0.112629
# [109]	test-rmse:0.124521	train-rmse:0.112265
# [110]	test-rmse:0.124383	train-rmse:0.112033
# [111]	test-rmse:0.124172	train-rmse:0.11161
# [112]	test-rmse:0.124164	train-rmse:0.111532
# [113]	test-rmse:0.12411	train-rmse:0.111438
# [114]	test-rmse:0.123733	train-rmse:0.110997
# [115]	test-rmse:0.123724	train-rmse:0.110963
# [116]	test-rmse:0.123702	train-rmse:0.110925
# [117]	test-rmse:0.123517	train-rmse:0.110578
# [118]	test-rmse:0.123465	train-rmse:0.110126
# [119]	test-rmse:0.123538	train-rmse:0.109786
# [120]	test-rmse:0.123512	train-rmse:0.109742
# [121]	test-rmse:0.1235	train-rmse:0.109631
# [122]	test-rmse:0.123498	train-rmse:0.109622
# [123]	test-rmse:0.123488	train-rmse:0.109564
# [124]	test-rmse:0.123479	train-rmse:0.109453
# [125]	test-rmse:0.123422	train-rmse:0.109364
# [126]	test-rmse:0.12337	train-rmse:0.109302
# [127]	test-rmse:0.123355	train-rmse:0.109262
# [128]	test-rmse:0.123292	train-rmse:0.109161
# [129]	test-rmse:0.123264	train-rmse:0.109067
# [130]	test-rmse:0.122914	train-rmse:0.108617
# [131]	test-rmse:0.122785	train-rmse:0.108407
# [132]	test-rmse:0.122706	train-rmse:0.108137
# [133]	test-rmse:0.122702	train-rmse:0.108096
# [134]	test-rmse:0.122571	train-rmse:0.107628
# [135]	test-rmse:0.122387	train-rmse:0.10713
# [136]	test-rmse:0.122352	train-rmse:0.107046
# [137]	test-rmse:0.122358	train-rmse:0.106911
# [138]	test-rmse:0.122346	train-rmse:0.106881
# [139]	test-rmse:0.122314	train-rmse:0.106699
# [140]	test-rmse:0.122266	train-rmse:0.106606
# [141]	test-rmse:0.122243	train-rmse:0.106471
# [142]	test-rmse:0.122147	train-rmse:0.106314
# [143]	test-rmse:0.12214	train-rmse:0.1063
# [144]	test-rmse:0.122076	train-rmse:0.106202
# [145]	test-rmse:0.121733	train-rmse:0.10565
# [146]	test-rmse:0.121683	train-rmse:0.105524
# [147]	test-rmse:0.121662	train-rmse:0.105458
# [148]	test-rmse:0.121601	train-rmse:0.105356
# [149]	test-rmse:0.121611	train-rmse:0.105147
# [150]	test-rmse:0.121538	train-rmse:0.104795
# [151]	test-rmse:0.121521	train-rmse:0.1047
# [152]	test-rmse:0.121479	train-rmse:0.104636
# [153]	test-rmse:0.121475	train-rmse:0.104624
# [154]	test-rmse:0.12148	train-rmse:0.104565
# [155]	test-rmse:0.121536	train-rmse:0.104303
# [156]	test-rmse:0.121407	train-rmse:0.104147
# [157]	test-rmse:0.121373	train-rmse:0.104077
# [158]	test-rmse:0.121358	train-rmse:0.103926
# [159]	test-rmse:0.121342	train-rmse:0.103829
# [160]	test-rmse:0.121333	train-rmse:0.103808
# [161]	test-rmse:0.121223	train-rmse:0.103362
# [162]	test-rmse:0.120968	train-rmse:0.103052
# [163]	test-rmse:0.120941	train-rmse:0.103004
# [164]	test-rmse:0.120942	train-rmse:0.102958
# [165]	test-rmse:0.120925	train-rmse:0.102932
# [166]	test-rmse:0.120835	train-rmse:0.102831
# [167]	test-rmse:0.120787	train-rmse:0.102748
# [168]	test-rmse:0.120747	train-rmse:0.10264
# [169]	test-rmse:0.120745	train-rmse:0.102636
# [170]	test-rmse:0.120743	train-rmse:0.102622
# [171]	test-rmse:0.120711	train-rmse:0.102436
# [172]	test-rmse:0.120692	train-rmse:0.102318
# [173]	test-rmse:0.120697	train-rmse:0.102286
# [174]	test-rmse:0.12068	train-rmse:0.102197
# [175]	test-rmse:0.12066	train-rmse:0.102157
# [176]	test-rmse:0.120647	train-rmse:0.102079
# [177]	test-rmse:0.120641	train-rmse:0.101987
# [178]	test-rmse:0.120588	train-rmse:0.101895
# [179]	test-rmse:0.120575	train-rmse:0.10183
# [180]	test-rmse:0.120574	train-rmse:0.101819
# [181]	test-rmse:0.12057	train-rmse:0.101797
# [182]	test-rmse:0.120626	train-rmse:0.101642
# [183]	test-rmse:0.120612	train-rmse:0.101612
# [184]	test-rmse:0.120609	train-rmse:0.101591
# [185]	test-rmse:0.120587	train-rmse:0.101505
# [186]	test-rmse:0.120529	train-rmse:0.101442
# [187]	test-rmse:0.120515	train-rmse:0.101417
# [188]	test-rmse:0.120513	train-rmse:0.101398
# [189]	test-rmse:0.120506	train-rmse:0.101367
# [190]	test-rmse:0.120503	train-rmse:0.101355
# [191]	test-rmse:0.120455	train-rmse:0.101273
# [192]	test-rmse:0.120418	train-rmse:0.101132
# [193]	test-rmse:0.120414	train-rmse:0.101111
# [194]	test-rmse:0.120364	train-rmse:0.100911
# [195]	test-rmse:0.120365	train-rmse:0.100875
# [196]	test-rmse:0.12036	train-rmse:0.100859
# [197]	test-rmse:0.120312	train-rmse:0.10074
# [198]	test-rmse:0.120304	train-rmse:0.100634
# [199]	test-rmse:0.120301	train-rmse:0.100623

# %% [markdown]
# ### Validating

# %%
print("Validating")
train_probs = gbm.predict(xgb.DMatrix(X_test[features]))
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# Validating
# error 0.10720854346197543

# %% [markdown]
# RMSE

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="gain")
plt.title("XGBoost Feature Gain")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="weight")
plt.title("XGBoost Feature weight")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="cover")
plt.title("XGBoost Feature cover")
plt.show()

# %% [markdown]
# ### Predict on fake test set

# %%
train_probs = gbm.predict(xgb.DMatrix(test[features]))

# %%
test['_NumberOfSales'] = np.exp(gbm.predict(xgb.DMatrix(test[features])))-1
# Out:
# C:\Users\Mirko\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## BIP Error

# %%
from BIP import get_BIP_error
error1 = get_BIP_error(test)
# Out:
# Number of regions identified: 11
# BIP total error: 0.0444315461718197

# %%
diff=test['NumberOfSales']-test['_NumberOfSales']

# %%
diff.head(15).T
# Out:
# 670    -212.747070
# 671    2070.460938
# 672    -356.118652
# 674    -473.026855
# 675   -1303.062988
# 677   -1848.073242
# 678   -2160.660156
# 679   -2172.970703
# 680   -1432.466309
# 681    -185.285156
# 682    -684.897461
# 684      27.769531
# 685     744.705566
# 686   -1181.346680
# 687    -648.809082
# dtype: float32

# %%
diff.mean()
# Out:
# -48.67221450805664

# %%
train_probs.shape
# Out:
# (36911,)

# %%
#test['predicted'] = pd.Series([train_probs], index=test.index)
#test['predicted']=train_probs

# %%
compare = test[['NumberOfSales','_NumberOfSales']]

# %% [markdown]
# ### Saving TEST

# %%
#test.to_csv('./dataset/XGB5_fake_test.csv', index=False)

# %%
error = rmspe(test['_NumberOfSales'].values, test['NumberOfSales'].values)
print('error', error)
# Out:
# error 0.19567676584967392

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 14893           5468     4305.241211
# 14894           6795     6959.092773
# 14896           7035     7389.159668
# 14897           5437     6403.018066
# 14898           5725     6050.510254
# 14899           5143     6049.540527
# 14900           5589     6637.783203
# 14901           7520     6460.241211
# 14903           3927     5377.758301
# 14904           3682     4539.054688
# 14905           3601     4638.782715
# 14906           3383     4436.059082
# 14907           4627     5022.581055
# 14908           7250     7006.212891
# 14910           7161     7441.831543
# 14911           6252     6416.639648
# 14912           5092     6531.960449
# 14913           6056     5689.226562
# 14914           6610     6966.796875
# 14915           6889     7077.340332
# 14917           7256     8062.583984
# 14918           5437     6403.018066
# 14919           5755     6056.093262
# 14920           5610     5707.767090
# 14921           5732     6456.145020
# 14922           6222     6517.634277
# 14924           4278     4527.405273
# 14925           3720     4467.176270
# 14926           4153     4432.691895
# 14927           3965     4455.226562
# ...              ...             ...
# 15646           7308     7395.322266
# 15647           6085     6616.064453
# 15648           5232     6430.136719
# 15649           5318     6200.655762
# 15650           4956     5668.588867
# 15651           5238     5253.640625
# 15653           4906     4981.914062
# 15654           4637     4571.033691
# 15655           4487     4837.208008
# 15656           4724     4565.151367
# 15657           5461     4947.613281
# 15658           5351     4935.000000
# 15660           6989     7063.906250
# 15661           5695     6337.270020
# 15662           5101     5912.131348
# 15663           5429     5501.579590
# 15664           5650     5873.942383
# 15665           5022     4743.868164
# 15667           4751     5049.423828
# 15668           4288     4191.178223
# 15669           4509     4163.782227
# 16340           5921     5533.435547
# 16341           6406     4903.753418
# 16342           3053     3037.427490
# 16344           5846     5972.910645
# 16345           4333     4316.352051
# 16347           9605     9796.506836
# 16349           7700     7960.709473
# 16350           6697     6996.283203
# 16351           6753     6617.623535
#
# [100 rows x 2 columns]

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 14893           5468     4305.241211
# 14894           6795     6959.092773
# 14896           7035     7389.159668
# 14897           5437     6403.018066
# 14898           5725     6050.510254
# 14899           5143     6049.540527
# 14900           5589     6637.783203
# 14901           7520     6460.241211
# 14903           3927     5377.758301
# 14904           3682     4539.054688
# 14905           3601     4638.782715
# 14906           3383     4436.059082
# 14907           4627     5022.581055
# 14908           7250     7006.212891
# 14910           7161     7441.831543
# 14911           6252     6416.639648
# 14912           5092     6531.960449
# 14913           6056     5689.226562
# 14914           6610     6966.796875
# 14915           6889     7077.340332
# 14917           7256     8062.583984
# 14918           5437     6403.018066
# 14919           5755     6056.093262
# 14920           5610     5707.767090
# 14921           5732     6456.145020
# 14922           6222     6517.634277
# 14924           4278     4527.405273
# 14925           3720     4467.176270
# 14926           4153     4432.691895
# 14927           3965     4455.226562
# ...              ...             ...
# 15646           7308     7395.322266
# 15647           6085     6616.064453
# 15648           5232     6430.136719
# 15649           5318     6200.655762
# 15650           4956     5668.588867
# 15651           5238     5253.640625
# 15653           4906     4981.914062
# 15654           4637     4571.033691
# 15655           4487     4837.208008
# 15656           4724     4565.151367
# 15657           5461     4947.613281
# 15658           5351     4935.000000
# 15660           6989     7063.906250
# 15661           5695     6337.270020
# 15662           5101     5912.131348
# 15663           5429     5501.579590
# 15664           5650     5873.942383
# 15665           5022     4743.868164
# 15667           4751     5049.423828
# 15668           4288     4191.178223
# 15669           4509     4163.782227
# 16340           5921     5533.435547
# 16341           6406     4903.753418
# 16342           3053     3037.427490
# 16344           5846     5972.910645
# 16345           4333     4316.352051
# 16347           9605     9796.506836
# 16349           7700     7960.709473
# 16350           6697     6996.283203
# 16351           6753     6617.623535
#
# [100 rows x 2 columns]

# %%
#REAL
start = 500
end = 600
import matplotlib.pyplot as plt

y = compare.iloc[start:end,0].values
x_coordinate = [ 1 * i for i in range(len(y)) ]
plt.plot(x_coordinate,y)
plt.show()

# %%
import matplotlib.pyplot as plt

yhat = compare.iloc[start:end:1].values
x_coordinate = [ 1 * i for i in range(len(yhat)) ]
plt.plot(x_coordinate,yhat)
plt.legend(['Real', 'Predicted'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
#import matplotlib as mpl

#mpl.style.use("default")


plt.plot(x_coordinate,y)
plt.plot(x_coordinate,yhat)
plt.legend(['Predicted', 'Real'], loc='upper left')
plt.show()

# %%
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-f3f3bea90e90> in <module>()
#       1 indices = train_probs < 0
#       2 train_probs[indices] = 0
# ----> 3 error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
#       4 print('error', error)
#
# <ipython-input-23-8df05da968cb> in rmspe(yhat, y)
#      11 def rmspe(yhat, y):
#      12     w = ToWeight(y)
# ---> 13     rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
#      14     return rmspe
#      15
#
# ValueError: operands could not be broadcast together with shapes (19853,) (36911,)

# %%
test_probs = gbm.predict(xgb.DMatrix(test[features]))
indices = test_probs < 0
test_probs[indices] = 0
submission = pd.DataFrame({"Id": test["Id"], "Sales": np.exp(test_probs) - 1})
submission.to_csv("xgboost_kscript_submission.csv", index=False)

# %%
Y = df.iloc[:, 3]

# %%
Y
