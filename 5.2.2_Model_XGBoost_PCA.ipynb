# %% [markdown]
# # XGBoost model

# %%
import pandas as pd
import numpy as np
#from sklearn import cross_validation
from sklearn.model_selection import cross_validate
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import validation_curve

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['figure.figsize'] = [20.0,8.0]
plt.rcParams['figure.dpi']=80

import modify_dataset as md

# %%
#Common error function to minimize: Root Mean Square Percentage Error
#We will have to integrate our loss function with xgboost

def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    return w


def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
    return rmspe


def rmspe_xg(yhat, y):
    # y = y.values
    y = y.get_label()
    y = np.exp(y) - 1
    yhat = np.exp(yhat) - 1
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat)**2))
    return "rmspe", rmspe

# %%
df = pd.read_csv("dataset/preprocessed_train_PCA.csv")

# %%
# column only for pca
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head().T
# Out:
#                                         0             1             2  \
# StoreID                              1000          1000          1000
# Date                           01/03/2016    02/03/2016    04/03/2016
# IsHoliday                               0             0             0
# IsOpen                                  1             1             1
# HasPromotions                           0             0             0
# StoreType                    Hyper Market  Hyper Market  Hyper Market
# AssortmentType                    General       General       General
# NearestCompetitor                     326           326           326
# Region                                  7             7             7
# NumberOfCustomers                     495           608           665
# NumberOfSales                        5676          8111          8300
# Region_AreaKM2                       9643          9643          9643
# Region_GDP                          17130         17130         17130
# Region_PopulationK                   2770          2770          2770
# CloudCover                              8             8             8
# Events                          Rain-Snow          Snow          Rain
# Max_VisibilityKm                        0             1             2
# Min_VisibilitykM                        0             1             2
# WindDirDegrees                         23            56            22
# D_Day                                   1             2             4
# D_DayOfYear                            61            62            64
# D_Month                                 3             3             3
# D_Year                               2016          2016          2016
# D_DayOfweek                             1             2             4
# StoreType_SuperMarket                   0             0             0
# StoreType_HyperMarket                   1             1             1
# StoreType_StandardMarket                0             0             0
# StoreType_ShoppingCenter                0             0             0
# AssortmentType_General                  1             1             1
# AssortmentType_WithNFDept               0             0             0
# AssortmentType_WithFishDept             0             0             0
# MeanStoreSales                    6296.18       6296.18       6296.18
# MeanRegionSales                   3906.26       3906.26       3906.26
# D_DayOfWeek_cos                   0.62349     -0.222521     -0.900969
# D_DayOfWeek_sin                  0.781831      0.974928     -0.433884
# p1                              0.0038253    0.00380447    0.00215876
# p2                              0.0014332   0.000903979  -0.000101837
# p3                            -0.00076347  -0.000480038  -0.000370168
# p4                           -0.000912617  -0.000547427  -0.000560225
# p5                            -0.00222642   -0.00247007   0.000554448
# p6                             0.00224159    0.00230143   -0.00110596
# p7                           -0.000719875    0.00107936  -0.000526003
# p8                            -0.00116095   -0.00118984   -0.00130027
# p9                            0.000247264   4.99143e-05  -0.000166103
# p10                           -0.00013257   0.000141136  -0.000514758
# p11                          -0.000344916  -0.000293834  -0.000337692
# p12                           -4.3497e-05    0.00016746   0.000414398
#
#                                         3             4
# StoreID                              1000          1000
# Date                           05/03/2016    06/03/2016
# IsHoliday                               0             0
# IsOpen                                  1             0
# HasPromotions                           0             0
# StoreType                    Hyper Market  Hyper Market
# AssortmentType                    General       General
# NearestCompetitor                     326           326
# Region                                  7             7
# NumberOfCustomers                     630             0
# NumberOfSales                        7154             0
# Region_AreaKM2                       9643          9643
# Region_GDP                          17130         17130
# Region_PopulationK                   2770          2770
# CloudCover                              6             6
# Events                               None          None
# Max_VisibilityKm                        3             4
# Min_VisibilitykM                        3             4
# WindDirDegrees                        108            46
# D_Day                                   5             6
# D_DayOfYear                            65            66
# D_Month                                 3             3
# D_Year                               2016          2016
# D_DayOfweek                             5             6
# StoreType_SuperMarket                   0             0
# StoreType_HyperMarket                   1             1
# StoreType_StandardMarket                0             0
# StoreType_ShoppingCenter                0             0
# AssortmentType_General                  1             1
# AssortmentType_WithNFDept               0             0
# AssortmentType_WithFishDept             0             0
# MeanStoreSales                    6296.18       6296.18
# MeanRegionSales                   3906.26       3906.26
# D_DayOfWeek_cos                 -0.222521       0.62349
# D_DayOfWeek_sin                 -0.974928     -0.781831
# p1                             0.00293107    0.00309834
# p2                           -0.000539355  -0.000536302
# p3                           -0.000204276  -0.000227628
# p4                           -0.000257912   5.16001e-05
# p5                            0.000438362   0.000510366
# p6                            -0.00145466   -0.00135293
# p7                             0.00139192    0.00121386
# p8                            -0.00117349   -0.00137445
# p9                            0.000203075  -0.000510994
# p10                          -0.000551018  -0.000225884
# p11                          -0.000326059   0.000393414
# p12                            0.00025032   2.78224e-05

# %%
# removing all rows for which store is closed
df = df[df.IsOpen == 1]

df.drop(['NumberOfCustomers','Date'], axis=1, inplace=True)
#df = df.drop(['Region','Events'], axis=1)
# I could leave events

# %%
#for now let's drop unusable categorical vars
df.drop(['StoreType','AssortmentType','Events'], axis=1, inplace=True)
df.head().T
# Out:
#                                         0             1             2  \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    0.000000      0.000000      0.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 5676.000000   8111.000000   8300.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       8.000000      8.000000      8.000000
# Max_VisibilityKm                 0.000000      1.000000      2.000000
# Min_VisibilitykM                 0.000000      1.000000      2.000000
# WindDirDegrees                  23.000000     56.000000     22.000000
# D_Day                            1.000000      2.000000      4.000000
# D_DayOfYear                     61.000000     62.000000     64.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      1.000000      2.000000      4.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                  0.623490     -0.222521     -0.900969
# D_DayOfWeek_sin                  0.781831      0.974928     -0.433884
# p1                               0.003825      0.003804      0.002159
# p2                               0.001433      0.000904     -0.000102
# p3                              -0.000763     -0.000480     -0.000370
# p4                              -0.000913     -0.000547     -0.000560
# p5                              -0.002226     -0.002470      0.000554
# p6                               0.002242      0.002301     -0.001106
# p7                              -0.000720      0.001079     -0.000526
# p8                              -0.001161     -0.001190     -0.001300
# p9                               0.000247      0.000050     -0.000166
# p10                             -0.000133      0.000141     -0.000515
# p11                             -0.000345     -0.000294     -0.000338
# p12                             -0.000043      0.000167      0.000414
#
#                                         3             5
# StoreID                       1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000
# IsOpen                           1.000000      1.000000
# HasPromotions                    0.000000      1.000000
# NearestCompetitor              326.000000    326.000000
# Region                           7.000000      7.000000
# NumberOfSales                 7154.000000  10110.000000
# Region_AreaKM2                9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000
# CloudCover                       6.000000      0.000000
# Max_VisibilityKm                 3.000000      5.000000
# Min_VisibilitykM                 3.000000      5.000000
# WindDirDegrees                 108.000000     68.000000
# D_Day                            5.000000      7.000000
# D_DayOfYear                     65.000000     67.000000
# D_Month                          3.000000      3.000000
# D_Year                        2016.000000   2016.000000
# D_DayOfweek                      5.000000      0.000000
# StoreType_SuperMarket            0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000
# AssortmentType_General           1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521      1.000000
# D_DayOfWeek_sin                 -0.974928      0.000000
# p1                               0.002931      0.002613
# p2                              -0.000539     -0.000531
# p3                              -0.000204     -0.000171
# p4                              -0.000258     -0.000311
# p5                               0.000438      0.000404
# p6                              -0.001455     -0.001347
# p7                               0.001392      0.001290
# p8                              -0.001173     -0.001128
# p9                               0.000203      0.000372
# p10                             -0.000551     -0.000353
# p11                             -0.000326      0.000050
# p12                              0.000250      0.000292

# %%
df.head(20).T
# Out:
#                                        0             1             2   \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    0.000000      0.000000      0.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 5676.000000   8111.000000   8300.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       8.000000      8.000000      8.000000
# Max_VisibilityKm                 0.000000      1.000000      2.000000
# Min_VisibilitykM                 0.000000      1.000000      2.000000
# WindDirDegrees                  23.000000     56.000000     22.000000
# D_Day                            1.000000      2.000000      4.000000
# D_DayOfYear                     61.000000     62.000000     64.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      1.000000      2.000000      4.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                  0.623490     -0.222521     -0.900969
# D_DayOfWeek_sin                  0.781831      0.974928     -0.433884
# p1                               0.003825      0.003804      0.002159
# p2                               0.001433      0.000904     -0.000102
# p3                              -0.000763     -0.000480     -0.000370
# p4                              -0.000913     -0.000547     -0.000560
# p5                              -0.002226     -0.002470      0.000554
# p6                               0.002242      0.002301     -0.001106
# p7                              -0.000720      0.001079     -0.000526
# p8                              -0.001161     -0.001190     -0.001300
# p9                               0.000247      0.000050     -0.000166
# p10                             -0.000133      0.000141     -0.000515
# p11                             -0.000345     -0.000294     -0.000338
# p12                             -0.000043      0.000167      0.000414
#
#                                        3             5             6   \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    0.000000      1.000000      1.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 7154.000000  10110.000000   9019.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       6.000000      0.000000      0.000000
# Max_VisibilityKm                 3.000000      5.000000      6.000000
# Min_VisibilitykM                 3.000000      5.000000      6.000000
# WindDirDegrees                 108.000000     68.000000     62.000000
# D_Day                            5.000000      7.000000      8.000000
# D_DayOfYear                     65.000000     67.000000     68.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      5.000000      0.000000      1.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521      1.000000      0.623490
# D_DayOfWeek_sin                 -0.974928      0.000000      0.781831
# p1                               0.002931      0.002613      0.002367
# p2                              -0.000539     -0.000531     -0.000662
# p3                              -0.000204     -0.000171     -0.000085
# p4                              -0.000258     -0.000311     -0.000192
# p5                               0.000438      0.000404      0.000326
# p6                              -0.001455     -0.001347     -0.001209
# p7                               0.001392      0.001290      0.001487
# p8                              -0.001173     -0.001128     -0.001246
# p9                               0.000203      0.000372     -0.000064
# p10                             -0.000551     -0.000353     -0.000653
# p11                             -0.000326      0.000050     -0.000044
# p12                              0.000250      0.000292      0.000007
#
#                                        7             8             9   \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    1.000000      1.000000      1.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 8804.000000   7823.000000   7989.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       0.000000      7.000000      7.000000
# Max_VisibilityKm                 7.000000      8.000000      9.000000
# Min_VisibilitykM                 7.000000      8.000000      9.000000
# WindDirDegrees                  53.000000     54.000000     30.000000
# D_Day                            9.000000     10.000000     11.000000
# D_DayOfYear                     69.000000     70.000000     71.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      2.000000      3.000000      4.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521     -0.900969     -0.900969
# D_DayOfWeek_sin                  0.974928      0.433884     -0.433884
# p1                               0.001858      0.000473     -0.000417
# p2                              -0.000675     -0.000457     -0.000287
# p3                              -0.000023     -0.000015     -0.000018
# p4                              -0.000307     -0.000647     -0.000792
# p5                               0.000255      0.000168      0.000233
# p6                              -0.001034     -0.000540     -0.000106
# p7                               0.001395     -0.000026     -0.000303
# p8                              -0.001193     -0.001330     -0.001289
# p9                               0.000125     -0.000295     -0.000152
# p10                             -0.000469     -0.001379     -0.000605
# p11                              0.000078     -0.000204     -0.000213
# p12                             -0.000106     -0.000048     -0.000168
#
#                                        10            12            13  \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    0.000000      0.000000      0.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 5895.000000   6348.000000   4738.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       6.000000      7.000000      7.000000
# Max_VisibilityKm                10.000000     12.000000     13.000000
# Min_VisibilitykM                10.000000     12.000000     13.000000
# WindDirDegrees                 202.000000     26.000000     26.000000
# D_Day                           12.000000     14.000000     15.000000
# D_DayOfYear                     72.000000     74.000000     75.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      5.000000      0.000000      1.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521      1.000000      0.623490
# D_DayOfWeek_sin                 -0.974928      0.000000      0.781831
# p1                              -0.000215      0.004549      0.004855
# p2                              -0.000300      0.001529      0.002806
# p3                              -0.000019     -0.000878     -0.001446
# p4                              -0.000840     -0.000915      0.001780
# p5                               0.000170     -0.002102     -0.000269
# p6                              -0.000220      0.001889      0.002901
# p7                              -0.000695     -0.000662     -0.000844
# p8                              -0.001245     -0.001052     -0.000794
# p9                               0.000023      0.000651      0.001617
# p10                             -0.000104     -0.000374      0.000021
# p11                              0.000305     -0.000104     -0.000568
# p12                              0.000121     -0.000086     -0.000151
#
#                                        14            15            16  \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    0.000000      0.000000      0.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 6014.000000   6087.000000   6962.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       5.000000      4.000000      2.000000
# Max_VisibilityKm                14.000000     15.000000     16.000000
# Min_VisibilitykM                14.000000     15.000000     16.000000
# WindDirDegrees                  27.000000    272.000000    218.000000
# D_Day                           16.000000     17.000000     18.000000
# D_DayOfYear                     76.000000     77.000000     78.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      2.000000      3.000000      4.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521     -0.900969     -0.900969
# D_DayOfWeek_sin                  0.974928      0.433884     -0.433884
# p1                               0.005906      0.006200      0.006207
# p2                               0.001121      0.001224      0.001069
# p3                              -0.000796     -0.000889     -0.000801
# p4                              -0.000397     -0.000007     -0.000272
# p5                              -0.002118     -0.001909     -0.002102
# p6                               0.001415      0.001458      0.001287
# p7                               0.001238      0.001394      0.001463
# p8                              -0.001075     -0.001243     -0.001115
# p9                               0.000480     -0.000107      0.000341
# p10                             -0.000360     -0.000654     -0.000818
# p11                             -0.000204      0.000867     -0.000016
# p12                              0.000142     -0.000099      0.000070
#
#                                        17            19            20  \
# StoreID                       1000.000000   1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000      0.000000
# IsOpen                           1.000000      1.000000      1.000000
# HasPromotions                    0.000000      1.000000      1.000000
# NearestCompetitor              326.000000    326.000000    326.000000
# Region                           7.000000      7.000000      7.000000
# NumberOfSales                 6618.000000   9183.000000   8155.000000
# Region_AreaKM2                9643.000000   9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000   2770.000000
# CloudCover                       0.000000      6.000000      4.000000
# Max_VisibilityKm                17.000000     19.000000     20.000000
# Min_VisibilitykM                17.000000     19.000000     20.000000
# WindDirDegrees                 138.000000    190.000000    211.000000
# D_Day                           19.000000     21.000000     22.000000
# D_DayOfYear                     79.000000     81.000000     82.000000
# D_Month                          3.000000      3.000000      3.000000
# D_Year                        2016.000000   2016.000000   2016.000000
# D_DayOfweek                      5.000000      0.000000      1.000000
# StoreType_SuperMarket            0.000000      0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000      0.000000
# AssortmentType_General           1.000000      1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521      1.000000      0.623490
# D_DayOfWeek_sin                 -0.974928      0.000000      0.781831
# p1                               0.003895      0.001802      0.001832
# p2                              -0.000524     -0.001042     -0.000466
# p3                              -0.000310      0.000374      0.000070
# p4                              -0.000148      0.002117      0.001741
# p5                               0.000539      0.000427      0.000681
# p6                              -0.001910     -0.000453     -0.000564
# p7                               0.001755      0.000626     -0.001235
# p8                              -0.001139     -0.001027     -0.000933
# p9                               0.000336      0.000759      0.001202
# p10                             -0.001390     -0.000305     -0.000471
# p11                             -0.000301     -0.000162      0.000449
# p12                              0.000543     -0.000405      0.000204
#
#                                        21            22
# StoreID                       1000.000000   1000.000000
# IsHoliday                        0.000000      0.000000
# IsOpen                           1.000000      1.000000
# HasPromotions                    1.000000      1.000000
# NearestCompetitor              326.000000    326.000000
# Region                           7.000000      7.000000
# NumberOfSales                 7109.000000   8041.000000
# Region_AreaKM2                9643.000000   9643.000000
# Region_GDP                   17130.000000  17130.000000
# Region_PopulationK            2770.000000   2770.000000
# CloudCover                       6.000000      6.000000
# Max_VisibilityKm                21.000000     22.000000
# Min_VisibilitykM                21.000000     22.000000
# WindDirDegrees                 191.000000    331.000000
# D_Day                           23.000000     24.000000
# D_DayOfYear                     83.000000     84.000000
# D_Month                          3.000000      3.000000
# D_Year                        2016.000000   2016.000000
# D_DayOfweek                      2.000000      3.000000
# StoreType_SuperMarket            0.000000      0.000000
# StoreType_HyperMarket            1.000000      1.000000
# StoreType_StandardMarket         0.000000      0.000000
# StoreType_ShoppingCenter         0.000000      0.000000
# AssortmentType_General           1.000000      1.000000
# AssortmentType_WithNFDept        0.000000      0.000000
# AssortmentType_WithFishDept      0.000000      0.000000
# MeanStoreSales                6296.182442   6296.182442
# MeanRegionSales               3906.263994   3906.263994
# D_DayOfWeek_cos                 -0.222521     -0.900969
# D_DayOfWeek_sin                  0.974928      0.433884
# p1                               0.001017      0.003921
# p2                               0.001390      0.001326
# p3                              -0.001095     -0.000718
# p4                              -0.000321     -0.000839
# p5                               0.001969     -0.002283
# p6                              -0.000093      0.002138
# p7                               0.000009     -0.000332
# p8                              -0.001228     -0.001173
# p9                               0.000106      0.000198
# p10                             -0.000387     -0.000910
# p11                              0.000579     -0.000282
# p12                              0.000234      0.000193

# %%
df.shape
# Out:
# (433958, 42)

# %%
train = md.get_fake_train(df)

# %%
train.shape
# Out:
# (397047, 42)

# %%
test = md.get_fake_test(df)
test.shape
# Out:
# (36911, 42)

# %%
#print("Load the training, test and store data using pandas")
#train = pd.read_csv("train.csv",low_memory=False)
#test = pd.read_csv("test.csv")
#store = pd.read_csv("store.csv")

# %% [markdown]
# ### Selecting predictive features

# %%
from pprint import pprint
features = list(train.columns.values)
features.remove('NumberOfSales')
features.remove('StoreID')
features.remove('IsOpen')
features.remove('D_DayOfweek')
#features.remove('Region')
#features.remove('Region_GDP')
#features.remove('Max_Dew_PointC')
#features.remove('Min_Dew_PointC')
#features.remove('Max_Wind_SpeedKm_h')
#features.remove('Max_VisibilityKm')
#features.remove('Min_Sea_Level_PressurehPa')
#features.remove('Precipitationmm')
#features.remove('Mean_Dew_PointC')
#features.remove('Min_TemperatureC')
#features.remove('Events_Thunderstorm')
#features.remove('Events_Fog')

print("features")

pprint(features)
# Out:
# features
# ['IsHoliday',
#  'HasPromotions',
#  'NearestCompetitor',
#  'Region',
#  'Region_AreaKM2',
#  'Region_GDP',
#  'Region_PopulationK',
#  'CloudCover',
#  'Max_VisibilityKm',
#  'Min_VisibilitykM',
#  'WindDirDegrees',
#  'D_Day',
#  'D_DayOfYear',
#  'D_Month',
#  'D_Year',
#  'StoreType_SuperMarket',
#  'StoreType_HyperMarket',
#  'StoreType_StandardMarket',
#  'StoreType_ShoppingCenter',
#  'AssortmentType_General',
#  'AssortmentType_WithNFDept',
#  'AssortmentType_WithFishDept',
#  'MeanStoreSales',
#  'MeanRegionSales',
#  'D_DayOfWeek_cos',
#  'D_DayOfWeek_sin',
#  'p1',
#  'p2',
#  'p3',
#  'p4',
#  'p5',
#  'p6',
#  'p7',
#  'p8',
#  'p9',
#  'p10',
#  'p11',
#  'p12']

# %%
# remove less relevant components
#features.remove('p6')
features.remove('p8')
features.remove('p4')
features.remove('p3')
features.remove('p9')

# %%
params = {"objective": "reg:linear",
          "eta": 0.2,
          "max_depth": 8,
          "subsample": 1.0,
          "colsample_bytree": 0.3, #0.3
          "silent": 1,
          "nthread":-1,
          #added as a test
          "eval_metric": "rmse",
          #"gamma": 2  #added as a test
          }

#reg_alpha 
#reg_lambda
num_trees = 200 #400

# %%
#split in train and test (not real test which is called test and is the fake test provided by md)
X_train, X_test = train_test_split(train, test_size=0.05)
#X_train, X_test = train.head(len(train) - val_size), train.tail(val_size)

# %%
dtrain = xgb.DMatrix(X_train[features], np.log(X_train["NumberOfSales"] + 1))
dvalid = xgb.DMatrix(X_test[features], np.log(X_test["NumberOfSales"] + 1))
#dtest = xgb.DMatrix(test[features])

# %%
X_train.shape
# Out:
# (377194, 42)

# %%
X_test.shape
# Out:
# (19853, 42)

# %%
#watchlist = [(dvalid, 'test'), (dtrain, 'train')]
#gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, feval=rmspe_xg, verbose_eval=True)

# %%
watchlist = [(dvalid, 'test'), (dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, verbose_eval=True)
# Out:
# [0]	test-rmse:6.33776	train-rmse:6.33633
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 20 rounds.
# [1]	test-rmse:5.07286	train-rmse:5.0715
# [2]	test-rmse:4.06356	train-rmse:4.06226
# [3]	test-rmse:3.25773	train-rmse:3.25604
# [4]	test-rmse:2.61432	train-rmse:2.61205
# [5]	test-rmse:2.09644	train-rmse:2.09414
# [6]	test-rmse:1.68674	train-rmse:1.68398
# [7]	test-rmse:1.35773	train-rmse:1.35463
# [8]	test-rmse:1.09827	train-rmse:1.09451
# [9]	test-rmse:0.887258	train-rmse:0.882871
# [10]	test-rmse:0.720515	train-rmse:0.715154
# [11]	test-rmse:0.59076	train-rmse:0.584474
# [12]	test-rmse:0.490473	train-rmse:0.482753
# [13]	test-rmse:0.412099	train-rmse:0.402655
# [14]	test-rmse:0.351503	train-rmse:0.340217
# [15]	test-rmse:0.303837	train-rmse:0.290752
# [16]	test-rmse:0.270407	train-rmse:0.255571
# [17]	test-rmse:0.245394	train-rmse:0.228922
# [18]	test-rmse:0.227257	train-rmse:0.209284
# [19]	test-rmse:0.214905	train-rmse:0.195542
# [20]	test-rmse:0.20532	train-rmse:0.184908
# [21]	test-rmse:0.198668	train-rmse:0.177599
# [22]	test-rmse:0.194234	train-rmse:0.17211
# [23]	test-rmse:0.190856	train-rmse:0.168078
# [24]	test-rmse:0.188644	train-rmse:0.16544
# [25]	test-rmse:0.185708	train-rmse:0.161982
# [26]	test-rmse:0.184522	train-rmse:0.160467
# [27]	test-rmse:0.181929	train-rmse:0.157359
# [28]	test-rmse:0.180011	train-rmse:0.154846
# [29]	test-rmse:0.178836	train-rmse:0.153294
# [30]	test-rmse:0.177771	train-rmse:0.151926
# [31]	test-rmse:0.17694	train-rmse:0.150967
# [32]	test-rmse:0.176509	train-rmse:0.150251
# [33]	test-rmse:0.176118	train-rmse:0.149725
# [34]	test-rmse:0.175364	train-rmse:0.148541
# [35]	test-rmse:0.174571	train-rmse:0.14721
# [36]	test-rmse:0.174125	train-rmse:0.146342
# [37]	test-rmse:0.1739	train-rmse:0.145819
# [38]	test-rmse:0.173627	train-rmse:0.145411
# [39]	test-rmse:0.173013	train-rmse:0.144599
# [40]	test-rmse:0.172912	train-rmse:0.14445
# [41]	test-rmse:0.172683	train-rmse:0.144155
# [42]	test-rmse:0.172545	train-rmse:0.143888
# [43]	test-rmse:0.171891	train-rmse:0.143083
# [44]	test-rmse:0.171564	train-rmse:0.142544
# [45]	test-rmse:0.17145	train-rmse:0.142246
# [46]	test-rmse:0.171319	train-rmse:0.141733
# [47]	test-rmse:0.170884	train-rmse:0.140965
# [48]	test-rmse:0.170297	train-rmse:0.140317
# [49]	test-rmse:0.170116	train-rmse:0.139995
# [50]	test-rmse:0.169856	train-rmse:0.139516
# [51]	test-rmse:0.169393	train-rmse:0.138703
# [52]	test-rmse:0.167612	train-rmse:0.136413
# [53]	test-rmse:0.167306	train-rmse:0.135915
# [54]	test-rmse:0.166134	train-rmse:0.134468
# [55]	test-rmse:0.166094	train-rmse:0.134165
# [56]	test-rmse:0.165932	train-rmse:0.133925
# [57]	test-rmse:0.165455	train-rmse:0.133153
# [58]	test-rmse:0.165381	train-rmse:0.132974
# [59]	test-rmse:0.165074	train-rmse:0.132503
# [60]	test-rmse:0.164281	train-rmse:0.131403
# [61]	test-rmse:0.164233	train-rmse:0.131224
# [62]	test-rmse:0.164167	train-rmse:0.130957
# [63]	test-rmse:0.16332	train-rmse:0.129979
# [64]	test-rmse:0.162897	train-rmse:0.129353
# [65]	test-rmse:0.162602	train-rmse:0.128842
# [66]	test-rmse:0.162281	train-rmse:0.128239
# [67]	test-rmse:0.161816	train-rmse:0.127268
# [68]	test-rmse:0.161703	train-rmse:0.126812
# [69]	test-rmse:0.16166	train-rmse:0.126739
# [70]	test-rmse:0.161352	train-rmse:0.126166
# [71]	test-rmse:0.161313	train-rmse:0.125774
# [72]	test-rmse:0.161194	train-rmse:0.125653
# [73]	test-rmse:0.16113	train-rmse:0.125392
# [74]	test-rmse:0.161059	train-rmse:0.125261
# [75]	test-rmse:0.161083	train-rmse:0.124776
# [76]	test-rmse:0.160283	train-rmse:0.123555
# [77]	test-rmse:0.160206	train-rmse:0.12329
# [78]	test-rmse:0.160085	train-rmse:0.122986
# [79]	test-rmse:0.160067	train-rmse:0.122895
# [80]	test-rmse:0.159989	train-rmse:0.122708
# [81]	test-rmse:0.159938	train-rmse:0.122537
# [82]	test-rmse:0.159859	train-rmse:0.122311
# [83]	test-rmse:0.159802	train-rmse:0.122138
# [84]	test-rmse:0.159294	train-rmse:0.12191
# [85]	test-rmse:0.159287	train-rmse:0.121872
# [86]	test-rmse:0.159115	train-rmse:0.121412
# [87]	test-rmse:0.158271	train-rmse:0.120319
# [88]	test-rmse:0.158244	train-rmse:0.120261
# [89]	test-rmse:0.158206	train-rmse:0.120002
# [90]	test-rmse:0.158074	train-rmse:0.119718
# [91]	test-rmse:0.157957	train-rmse:0.119465
# [92]	test-rmse:0.157934	train-rmse:0.119252
# [93]	test-rmse:0.15785	train-rmse:0.118992
# [94]	test-rmse:0.157789	train-rmse:0.118743
# [95]	test-rmse:0.157673	train-rmse:0.118435
# [96]	test-rmse:0.157634	train-rmse:0.118325
# [97]	test-rmse:0.156791	train-rmse:0.117257
# [98]	test-rmse:0.156695	train-rmse:0.117145
# [99]	test-rmse:0.156487	train-rmse:0.116856
# [100]	test-rmse:0.156469	train-rmse:0.116731
# [101]	test-rmse:0.156433	train-rmse:0.116574
# [102]	test-rmse:0.15568	train-rmse:0.115417
# [103]	test-rmse:0.155362	train-rmse:0.114985
# [104]	test-rmse:0.155342	train-rmse:0.114859
# [105]	test-rmse:0.155334	train-rmse:0.114627
# [106]	test-rmse:0.155247	train-rmse:0.114507
# [107]	test-rmse:0.155239	train-rmse:0.11447
# [108]	test-rmse:0.155171	train-rmse:0.114327
# [109]	test-rmse:0.154888	train-rmse:0.113945
# [110]	test-rmse:0.154888	train-rmse:0.113762
# [111]	test-rmse:0.154892	train-rmse:0.113754
# [112]	test-rmse:0.154868	train-rmse:0.113609
# [113]	test-rmse:0.154787	train-rmse:0.113277
# [114]	test-rmse:0.154737	train-rmse:0.113175
# [115]	test-rmse:0.154727	train-rmse:0.113035
# [116]	test-rmse:0.154579	train-rmse:0.112861
# [117]	test-rmse:0.154525	train-rmse:0.112585
# [118]	test-rmse:0.154482	train-rmse:0.112473
# [119]	test-rmse:0.154465	train-rmse:0.112311
# [120]	test-rmse:0.154453	train-rmse:0.112154
# [121]	test-rmse:0.154448	train-rmse:0.112067
# [122]	test-rmse:0.154415	train-rmse:0.111934
# [123]	test-rmse:0.154362	train-rmse:0.11174
# [124]	test-rmse:0.154328	train-rmse:0.111599
# [125]	test-rmse:0.154314	train-rmse:0.111557
# [126]	test-rmse:0.153909	train-rmse:0.111076
# [127]	test-rmse:0.153873	train-rmse:0.110888
# [128]	test-rmse:0.153845	train-rmse:0.110764
# [129]	test-rmse:0.153362	train-rmse:0.110153
# [130]	test-rmse:0.15332	train-rmse:0.10998
# [131]	test-rmse:0.153319	train-rmse:0.109963
# [132]	test-rmse:0.152759	train-rmse:0.109229
# [133]	test-rmse:0.152724	train-rmse:0.109145
# [134]	test-rmse:0.15267	train-rmse:0.108834
# [135]	test-rmse:0.152548	train-rmse:0.108639
# [136]	test-rmse:0.152514	train-rmse:0.108548
# [137]	test-rmse:0.152295	train-rmse:0.108185
# [138]	test-rmse:0.152241	train-rmse:0.10799
# [139]	test-rmse:0.15222	train-rmse:0.107953
# [140]	test-rmse:0.152165	train-rmse:0.107834
# [141]	test-rmse:0.152165	train-rmse:0.107733
# [142]	test-rmse:0.151958	train-rmse:0.107442
# [143]	test-rmse:0.151525	train-rmse:0.106848
# [144]	test-rmse:0.151456	train-rmse:0.106707
# [145]	test-rmse:0.151417	train-rmse:0.106534
# [146]	test-rmse:0.151404	train-rmse:0.106387
# [147]	test-rmse:0.151378	train-rmse:0.106229
# [148]	test-rmse:0.15137	train-rmse:0.106189
# [149]	test-rmse:0.151361	train-rmse:0.106126
# [150]	test-rmse:0.151354	train-rmse:0.106105
# [151]	test-rmse:0.151306	train-rmse:0.106
# [152]	test-rmse:0.151306	train-rmse:0.105966
# [153]	test-rmse:0.15128	train-rmse:0.105764
# [154]	test-rmse:0.151261	train-rmse:0.105697
# [155]	test-rmse:0.15125	train-rmse:0.105589
# [156]	test-rmse:0.151238	train-rmse:0.105576
# [157]	test-rmse:0.151144	train-rmse:0.105098
# [158]	test-rmse:0.15114	train-rmse:0.105068
# [159]	test-rmse:0.151106	train-rmse:0.104836
# [160]	test-rmse:0.15111	train-rmse:0.104819
# [161]	test-rmse:0.151088	train-rmse:0.104675
# [162]	test-rmse:0.151007	train-rmse:0.104527
# [163]	test-rmse:0.150998	train-rmse:0.104426
# [164]	test-rmse:0.150994	train-rmse:0.104322
# [165]	test-rmse:0.15098	train-rmse:0.104161
# [166]	test-rmse:0.150981	train-rmse:0.104153
# [167]	test-rmse:0.150979	train-rmse:0.104129
# [168]	test-rmse:0.150804	train-rmse:0.103639
# [169]	test-rmse:0.150789	train-rmse:0.10355
# [170]	test-rmse:0.150724	train-rmse:0.103408
# [171]	test-rmse:0.150699	train-rmse:0.103279
# [172]	test-rmse:0.150671	train-rmse:0.103218
# [173]	test-rmse:0.150607	train-rmse:0.103138
# [174]	test-rmse:0.150484	train-rmse:0.102976
# [175]	test-rmse:0.150482	train-rmse:0.102788
# [176]	test-rmse:0.150428	train-rmse:0.102685
# [177]	test-rmse:0.150355	train-rmse:0.102399
# [178]	test-rmse:0.150277	train-rmse:0.102253
# [179]	test-rmse:0.15017	train-rmse:0.102127
# [180]	test-rmse:0.150172	train-rmse:0.102046
# [181]	test-rmse:0.150161	train-rmse:0.101949
# [182]	test-rmse:0.150154	train-rmse:0.101917
# [183]	test-rmse:0.150158	train-rmse:0.101886
# [184]	test-rmse:0.150135	train-rmse:0.101825
# [185]	test-rmse:0.149081	train-rmse:0.101654
# [186]	test-rmse:0.149016	train-rmse:0.101385
# [187]	test-rmse:0.149004	train-rmse:0.101282
# [188]	test-rmse:0.149004	train-rmse:0.101236
# [189]	test-rmse:0.149005	train-rmse:0.101223
# [190]	test-rmse:0.148976	train-rmse:0.101158
# [191]	test-rmse:0.148917	train-rmse:0.101031
# [192]	test-rmse:0.148918	train-rmse:0.100952
# [193]	test-rmse:0.148868	train-rmse:0.100777
# [194]	test-rmse:0.148873	train-rmse:0.100759
# [195]	test-rmse:0.148848	train-rmse:0.100686
# [196]	test-rmse:0.148766	train-rmse:0.100565
# [197]	test-rmse:0.148757	train-rmse:0.100422
# [198]	test-rmse:0.148586	train-rmse:0.10015
# [199]	test-rmse:0.148583	train-rmse:0.100114

# %% [markdown]
# ### Validating

# %%
print("Validating")
train_probs = gbm.predict(xgb.DMatrix(X_test[features]))
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# Validating
# error 0.1089256791956602

# %% [markdown]
# RMSE

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['figure.figsize'] = [20.0,8.0]
plt.rcParams['figure.dpi']=80

# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="gain")
plt.title("XGBoost Feature Gain")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="weight")
plt.title("XGBoost Feature weight")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="cover")
plt.title("XGBoost Feature cover")
plt.show()

# %% [markdown]
# ### Predict on fake test set

# %%
train_probs = gbm.predict(xgb.DMatrix(test[features]))

# %%
test['_NumberOfSales'] = np.exp(gbm.predict(xgb.DMatrix(test[features])))-1
# Out:
# /home/nyxgear/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## BIP Error

# %%
from BIP_error import get_BIP_error
error1 = get_BIP_error(test)
# Out:
# Number of regions identified: 11
# BIP total error: 0.04516873024811466

# %%
diff=test['NumberOfSales']-test['_NumberOfSales']

# %%
diff.head(15).T
# Out:
# 670    -151.287109
# 671    1794.520508
# 672    -362.232910
# 674    -649.259277
# 675    -417.408691
# 677   -2213.343750
# 678   -1454.741211
# 679   -1185.349609
# 680   -1220.404785
# 681    -664.436523
# 682    -221.133789
# 684     121.257812
# 685     489.625000
# 686    -657.870117
# 687    -876.978516
# dtype: float32

# %%
diff.mean()
# Out:
# -51.711788177490234

# %%
train_probs.shape
# Out:
# (36911,)

# %%
#test['predicted'] = pd.Series([train_probs], index=test.index)
#test['predicted']=train_probs

# %%
compare = test[['NumberOfSales','_NumberOfSales']]

# %% [markdown]
# ### Saving TEST

# %%
#test.to_csv('./dataset/XGB5_fake_test.csv', index=False)

# %%
error = rmspe(test['_NumberOfSales'].values, test['NumberOfSales'].values)
print('error', error)
# Out:
# error 0.19920641329950234

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 14893           5468     6616.973633
# 14894           6795     7126.545410
# 14896           7035     6819.748047
# 14897           5437     5678.183105
# 14898           5725     6191.070312
# 14899           5143     6215.150879
# 14900           5589     6539.547363
# 14901           7520     5904.708984
# 14903           3927     4869.154785
# 14904           3682     4176.571289
# 14905           3601     4250.305664
# 14906           3383     4460.908203
# 14907           4627     4858.141113
# 14908           7250     5990.986816
# 14910           7161     6115.073730
# 14911           6252     5695.226074
# 14912           5092     6152.792969
# 14913           6056     6390.741699
# 14914           6610     6248.646484
# 14915           6889     7010.143555
# 14917           7256     8527.464844
# 14918           5437     6869.252930
# 14919           5755     6002.409180
# 14920           5610     5950.210938
# 14921           5732     6398.713379
# 14922           6222     5819.080078
# 14924           4278     4491.342285
# 14925           3720     4380.018555
# 14926           4153     4420.092773
# 14927           3965     4462.491211
# ...              ...             ...
# 15646           7308     8280.639648
# 15647           6085     6465.801758
# 15648           5232     6158.752930
# 15649           5318     6145.930664
# 15650           4956     5627.193848
# 15651           5238     4791.044434
# 15653           4906     4683.100098
# 15654           4637     4632.327148
# 15655           4487     4520.738281
# 15656           4724     4553.743164
# 15657           5461     4751.984375
# 15658           5351     4765.361328
# 15660           6989     7130.176270
# 15661           5695     6249.802734
# 15662           5101     5740.997559
# 15663           5429     5794.338867
# 15664           5650     5716.822754
# 15665           5022     4984.742188
# 15667           4751     4948.916016
# 15668           4288     4391.606934
# 15669           4509     4320.158203
# 16340           5921     5251.130371
# 16341           6406     5163.986816
# 16342           3053     3081.125732
# 16344           5846     5461.226562
# 16345           4333     4146.856934
# 16347           9605     9538.674805
# 16349           7700     7275.210449
# 16350           6697     6438.870117
# 16351           6753     6876.706543
#
# [100 rows x 2 columns]

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 14893           5468     6616.973633
# 14894           6795     7126.545410
# 14896           7035     6819.748047
# 14897           5437     5678.183105
# 14898           5725     6191.070312
# 14899           5143     6215.150879
# 14900           5589     6539.547363
# 14901           7520     5904.708984
# 14903           3927     4869.154785
# 14904           3682     4176.571289
# 14905           3601     4250.305664
# 14906           3383     4460.908203
# 14907           4627     4858.141113
# 14908           7250     5990.986816
# 14910           7161     6115.073730
# 14911           6252     5695.226074
# 14912           5092     6152.792969
# 14913           6056     6390.741699
# 14914           6610     6248.646484
# 14915           6889     7010.143555
# 14917           7256     8527.464844
# 14918           5437     6869.252930
# 14919           5755     6002.409180
# 14920           5610     5950.210938
# 14921           5732     6398.713379
# 14922           6222     5819.080078
# 14924           4278     4491.342285
# 14925           3720     4380.018555
# 14926           4153     4420.092773
# 14927           3965     4462.491211
# ...              ...             ...
# 15646           7308     8280.639648
# 15647           6085     6465.801758
# 15648           5232     6158.752930
# 15649           5318     6145.930664
# 15650           4956     5627.193848
# 15651           5238     4791.044434
# 15653           4906     4683.100098
# 15654           4637     4632.327148
# 15655           4487     4520.738281
# 15656           4724     4553.743164
# 15657           5461     4751.984375
# 15658           5351     4765.361328
# 15660           6989     7130.176270
# 15661           5695     6249.802734
# 15662           5101     5740.997559
# 15663           5429     5794.338867
# 15664           5650     5716.822754
# 15665           5022     4984.742188
# 15667           4751     4948.916016
# 15668           4288     4391.606934
# 15669           4509     4320.158203
# 16340           5921     5251.130371
# 16341           6406     5163.986816
# 16342           3053     3081.125732
# 16344           5846     5461.226562
# 16345           4333     4146.856934
# 16347           9605     9538.674805
# 16349           7700     7275.210449
# 16350           6697     6438.870117
# 16351           6753     6876.706543
#
# [100 rows x 2 columns]

# %%
#REAL
start = 500
end = 600
import matplotlib.pyplot as plt

y = compare.iloc[start:end,0].values
x_coordinate = [ 1 * i for i in range(len(y)) ]
plt.plot(x_coordinate,y)
plt.show()

# %%
import matplotlib.pyplot as plt

yhat = compare.iloc[start:end:1].values
x_coordinate = [ 1 * i for i in range(len(yhat)) ]
plt.plot(x_coordinate,yhat)
plt.legend(['Real', 'Predicted'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
#import matplotlib as mpl

#mpl.style.use("default")


plt.plot(x_coordinate,y)
plt.plot(x_coordinate,yhat)
plt.legend(['Predicted', 'Real'], loc='upper left')
plt.show()

# %%
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f3f3bea90e90> in <module>()
#       1 indices = train_probs < 0
#       2 train_probs[indices] = 0
# ----> 3 error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
#       4 print('error', error)
#
# <ipython-input-2-8df05da968cb> in rmspe(yhat, y)
#      11 def rmspe(yhat, y):
#      12     w = ToWeight(y)
# ---> 13     rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
#      14     return rmspe
#      15
#
# ValueError: operands could not be broadcast together with shapes (19853,) (36911,)

# %%
test_probs = gbm.predict(xgb.DMatrix(test[features]))
indices = test_probs < 0
test_probs[indices] = 0
submission = pd.DataFrame({"Id": test["Id"], "Sales": np.exp(test_probs) - 1})
submission.to_csv("xgboost_kscript_submission.csv", index=False)

# %%
Y = df.iloc[:, 3]

# %%
Y
