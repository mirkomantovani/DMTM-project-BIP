# %% [markdown]
# # XGBoost model

# %%
import pandas as pd
import numpy as np
#from sklearn import cross_validation
from sklearn.model_selection import cross_validate
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import validation_curve

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['figure.figsize'] = [20.0,8.0]
plt.rcParams['figure.dpi']=80

import modify_dataset as md

# %%
#Common error function to minimize: Root Mean Square Percentage Error
#We will have to integrate our loss function with xgboost

def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    return w


def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
    return rmspe


def rmspe_xg(yhat, y):
    # y = y.values
    y = y.get_label()
    y = np.exp(y) - 1
    yhat = np.exp(yhat) - 1
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat)**2))
    return "rmspe", rmspe

# %%
df = pd.read_csv("dataset/preprocessed_train_PCA.csv")

# %%
df = df.drop(['NumberOfCustomers'], axis=1)
#df = df.drop(['Region','Events'], axis=1)
# I could leave events

# %%
df = df[df.IsOpen == 1]

# %%
#for now let's drop unusable categorical vars
df = df.drop(['StoreType','AssortmentType','Events'], axis=1)

# %%
#only for pca
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head(20).T
# Out:
#                                       0            1            2   \
# StoreID                             1000         1000         1000
# Date                          01/03/2016   02/03/2016   04/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5676         8111         8300
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             8            8            8
# Max_VisibilityKm                       0            1            2
# Min_VisibilitykM                       0            1            2
# WindDirDegrees                        23           56           22
# D_Day                                  1            2            4
# D_DayOfYear                           61           62           64
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            1            2            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                  0.62349    -0.222521    -0.900969
# D_DayOfWeek_sin                 0.781831     0.974928    -0.433884
# p1                             0.0038253   0.00380447   0.00215876
# p2                             0.0014332  0.000903979 -0.000101837
# p3                           -0.00076347 -0.000480038 -0.000370168
# p4                          -0.000912617 -0.000547427 -0.000560225
# p5                           -0.00222642  -0.00247007  0.000554448
# p6                            0.00224159   0.00230143  -0.00110596
# p7                          -0.000719875   0.00107936 -0.000526003
# p8                           -0.00116095  -0.00118984  -0.00130027
# p9                           0.000247264  4.99143e-05 -0.000166103
# p10                          -0.00013257  0.000141136 -0.000514758
# p11                         -0.000344916 -0.000293834 -0.000337692
# p12                          -4.3497e-05   0.00016746  0.000414398
#
#                                       3            5            6   \
# StoreID                             1000         1000         1000
# Date                          05/03/2016   07/03/2016   08/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       7154        10110         9019
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            0            0
# Max_VisibilityKm                       3            5            6
# Min_VisibilitykM                       3            5            6
# WindDirDegrees                       108           68           62
# D_Day                                  5            7            8
# D_DayOfYear                           65           67           68
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                            0.00293107   0.00261322   0.00236662
# p2                          -0.000539355 -0.000531053 -0.000662307
# p3                          -0.000204276 -0.000171205 -8.46579e-05
# p4                          -0.000257912  -0.00031086 -0.000191952
# p5                           0.000438362  0.000403522  0.000326159
# p6                           -0.00145466   -0.0013466  -0.00120862
# p7                            0.00139192   0.00129003   0.00148701
# p8                           -0.00117349  -0.00112774  -0.00124582
# p9                           0.000203075   0.00037153 -6.42772e-05
# p10                         -0.000551018  -0.00035296 -0.000653497
# p11                         -0.000326059  5.03901e-05 -4.39029e-05
# p12                           0.00025032  0.000291776  7.02017e-06
#
#                                       7            8            9   \
# StoreID                             1000         1000         1000
# Date                          09/03/2016   10/03/2016   11/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          1            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       8804         7823         7989
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            7            7
# Max_VisibilityKm                       7            8            9
# Min_VisibilitykM                       7            8            9
# WindDirDegrees                        53           54           30
# D_Day                                  9           10           11
# D_DayOfYear                           69           70           71
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884    -0.433884
# p1                            0.00185775  0.000473164 -0.000416869
# p2                           -0.00067526 -0.000457064 -0.000287349
# p3                          -2.25402e-05 -1.45983e-05 -1.82241e-05
# p4                          -0.000306754 -0.000647226 -0.000792144
# p5                           0.000255091  0.000167626   0.00023278
# p6                           -0.00103422 -0.000539841 -0.000105736
# p7                            0.00139519 -2.56231e-05 -0.000303005
# p8                           -0.00119338  -0.00132962  -0.00128861
# p9                           0.000124802 -0.000294708 -0.000151588
# p10                         -0.000468897  -0.00137889 -0.000605416
# p11                          7.81451e-05 -0.000204166 -0.000212506
# p12                          -0.00010592 -4.79889e-05 -0.000167507
#
#                                       10           12           13  \
# StoreID                             1000         1000         1000
# Date                          12/03/2016   14/03/2016   15/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5895         6348         4738
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            7            7
# Max_VisibilityKm                      10           12           13
# Min_VisibilitykM                      10           12           13
# WindDirDegrees                       202           26           26
# D_Day                                 12           14           15
# D_DayOfYear                           72           74           75
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                           -0.00021493   0.00454891   0.00485476
# p2                          -0.000300094   0.00152879   0.00280597
# p3                          -1.93295e-05 -0.000878183  -0.00144622
# p4                          -0.000840343 -0.000915415   0.00177991
# p5                           0.000170166  -0.00210205 -0.000269195
# p6                            -0.0002203   0.00188936   0.00290054
# p7                          -0.000694627 -0.000661546 -0.000843696
# p8                           -0.00124548  -0.00105218 -0.000794234
# p9                           2.26767e-05  0.000650834   0.00161685
# p10                         -0.000104071 -0.000373564  2.09806e-05
# p11                          0.000304696 -0.000103976 -0.000567888
# p12                          0.000120549  -8.6487e-05 -0.000151292
#
#                                       14           15           16  \
# StoreID                             1000         1000         1000
# Date                          16/03/2016   17/03/2016   18/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6014         6087         6962
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             5            4            2
# Max_VisibilityKm                      14           15           16
# Min_VisibilitykM                      14           15           16
# WindDirDegrees                        27          272          218
# D_Day                                 16           17           18
# D_DayOfYear                           76           77           78
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884    -0.433884
# p1                            0.00590618   0.00619993   0.00620682
# p2                            0.00112061    0.0012244   0.00106947
# p3                           -0.00079585 -0.000888527 -0.000800649
# p4                          -0.000396647 -6.89417e-06 -0.000271905
# p5                           -0.00211805   -0.0019094  -0.00210155
# p6                            0.00141545   0.00145775   0.00128724
# p7                            0.00123804   0.00139421   0.00146344
# p8                           -0.00107538  -0.00124269  -0.00111452
# p9                           0.000479975 -0.000106806  0.000340916
# p10                         -0.000359549 -0.000654383 -0.000817936
# p11                         -0.000204156  0.000866687 -1.55093e-05
# p12                           0.00014157 -9.86859e-05   6.9519e-05
#
#                                       17           19           20  \
# StoreID                             1000         1000         1000
# Date                          19/03/2016   21/03/2016   22/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6618         9183         8155
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            6            4
# Max_VisibilityKm                      17           19           20
# Min_VisibilitykM                      17           19           20
# WindDirDegrees                       138          190          211
# D_Day                                 19           21           22
# D_DayOfYear                           79           81           82
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# D_DayOfWeek_cos                -0.222521            1      0.62349
# D_DayOfWeek_sin                -0.974928            0     0.781831
# p1                            0.00389524   0.00180157   0.00183232
# p2                           -0.00052353  -0.00104194 -0.000465838
# p3                          -0.000309571  0.000374328  7.00345e-05
# p4                          -0.000147691   0.00211691   0.00174133
# p5                           0.000539229  0.000427248   0.00068135
# p6                           -0.00190977 -0.000453241 -0.000564274
# p7                            0.00175458  0.000625665  -0.00123484
# p8                           -0.00113884  -0.00102667 -0.000933344
# p9                           0.000335526  0.000759144   0.00120153
# p10                           -0.0013901 -0.000305311 -0.000471439
# p11                         -0.000301076 -0.000162035  0.000449306
# p12                          0.000542752 -0.000404629  0.000203928
#
#                                       21           22
# StoreID                             1000         1000
# Date                          23/03/2016   24/03/2016
# IsHoliday                              0            0
# IsOpen                                 1            1
# HasPromotions                          1            1
# NearestCompetitor                    326          326
# Region                                 7            7
# NumberOfSales                       7109         8041
# Region_AreaKM2                      9643         9643
# Region_GDP                         17130        17130
# Region_PopulationK                  2770         2770
# CloudCover                             6            6
# Max_VisibilityKm                      21           22
# Min_VisibilitykM                      21           22
# WindDirDegrees                       191          331
# D_Day                                 23           24
# D_DayOfYear                           83           84
# D_Month                                3            3
# D_Year                              2016         2016
# D_DayOfweek                            2            3
# StoreType_SuperMarket                  0            0
# StoreType_HyperMarket                  1            1
# StoreType_StandardMarket               0            0
# StoreType_ShoppingCenter               0            0
# AssortmentType_General                 1            1
# AssortmentType_WithNFDept              0            0
# AssortmentType_WithFishDept            0            0
# MeanStoreSales                   6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26
# D_DayOfWeek_cos                -0.222521    -0.900969
# D_DayOfWeek_sin                 0.974928     0.433884
# p1                             0.0010165   0.00392148
# p2                            0.00139047   0.00132576
# p3                           -0.00109489 -0.000718271
# p4                          -0.000321022 -0.000839272
# p5                            0.00196911  -0.00228311
# p6                          -9.33638e-05   0.00213789
# p7                           9.40244e-06 -0.000332149
# p8                           -0.00122761  -0.00117337
# p9                           0.000106001  0.000198016
# p10                         -0.000386896 -0.000910045
# p11                          0.000579355 -0.000281794
# p12                          0.000234422  0.000193493

# %%
df.shape
# Out:
# (433958, 43)

# %%
train = md.get_fake_train(df)

# %%
train.shape
# Out:
# (397047, 43)

# %%
test = md.get_fake_test(df)
test.shape
# Out:
# (36911, 43)

# %%
#print("Load the training, test and store data using pandas")
#train = pd.read_csv("train.csv",low_memory=False)
#test = pd.read_csv("test.csv")
#store = pd.read_csv("store.csv")

# %% [markdown]
# ### Selecting predictive features

# %%
from pprint import pprint
features = list(train.columns.values)
features.remove('NumberOfSales')
features.remove('StoreID')
features.remove('IsOpen')
#features.remove('Region')
#features.remove('Region_GDP')
#features.remove('Max_Dew_PointC')
#features.remove('Min_Sea_Level_PressurehPa')
#features.remove('Precipitationmm')
#features.remove('Mean_Dew_PointC')
#features.remove('Min_TemperatureC')
#features.remove('Events_Thunderstorm')
#features.remove('Events_Fog')
features.remove('D_DayOfweek')
features.remove('Date')
print("features")

pprint(features)
# Out:
# features
# ['IsHoliday',
#  'HasPromotions',
#  'NearestCompetitor',
#  'Region',
#  'Region_AreaKM2',
#  'Region_GDP',
#  'Region_PopulationK',
#  'CloudCover',
#  'Max_VisibilityKm',
#  'Min_VisibilitykM',
#  'WindDirDegrees',
#  'D_Day',
#  'D_DayOfYear',
#  'D_Month',
#  'D_Year',
#  'StoreType_SuperMarket',
#  'StoreType_HyperMarket',
#  'StoreType_StandardMarket',
#  'StoreType_ShoppingCenter',
#  'AssortmentType_General',
#  'AssortmentType_WithNFDept',
#  'AssortmentType_WithFishDept',
#  'MeanStoreSales',
#  'MeanRegionSales',
#  'D_DayOfWeek_cos',
#  'D_DayOfWeek_sin',
#  'p1',
#  'p2',
#  'p3',
#  'p4',
#  'p5',
#  'p6',
#  'p7',
#  'p8',
#  'p9',
#  'p10',
#  'p11',
#  'p12']

# %%
features.remove('p6')
features.remove('p3')
features.remove('p7')
features.remove('p9')

# %%
params = {"objective": "reg:linear",
          "eta": 0.2,
          "max_depth": 8,
          "subsample": 1.0,
          "colsample_bytree": 0.3, #0.3
          "silent": 1,
          "nthread":-1,
          #added as a test
          "eval_metric": "rmse",
          #"gamma": 2  #added as a test
          }

#reg_alpha 
#reg_lambda
num_trees = 200 #400

# %%
#split in train and test (not real test which is called test and is the fake test provided by md)
X_train, X_test = train_test_split(train, test_size=0.05)
#X_train, X_test = train.head(len(train) - val_size), train.tail(val_size)

# %%
dtrain = xgb.DMatrix(X_train[features], np.log(X_train["NumberOfSales"] + 1))
dvalid = xgb.DMatrix(X_test[features], np.log(X_test["NumberOfSales"] + 1))
#dtest = xgb.DMatrix(test[features])

# %%
X_train.shape
# Out:
# (377194, 43)

# %%
X_test.shape
# Out:
# (19853, 43)

# %%
#watchlist = [(dvalid, 'test'), (dtrain, 'train')]
#gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, feval=rmspe_xg, verbose_eval=True)

# %%
watchlist = [(dvalid, 'test'), (dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, verbose_eval=True)
# Out:
# [0]	test-rmse:6.33602	train-rmse:6.33701
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 20 rounds.
# [1]	test-rmse:5.07396	train-rmse:5.07509
# [2]	test-rmse:4.06414	train-rmse:4.06551
# [3]	test-rmse:3.25474	train-rmse:3.25608
# [4]	test-rmse:2.61046	train-rmse:2.61202
# [5]	test-rmse:2.0935	train-rmse:2.09517
# [6]	test-rmse:1.68274	train-rmse:1.68451
# [7]	test-rmse:1.35582	train-rmse:1.35786
# [8]	test-rmse:1.09445	train-rmse:1.09657
# [9]	test-rmse:0.884044	train-rmse:0.886545
# [10]	test-rmse:0.71633	train-rmse:0.719339
# [11]	test-rmse:0.588182	train-rmse:0.591942
# [12]	test-rmse:0.484237	train-rmse:0.488703
# [13]	test-rmse:0.40211	train-rmse:0.407598
# [14]	test-rmse:0.339386	train-rmse:0.346048
# [15]	test-rmse:0.294163	train-rmse:0.301807
# [16]	test-rmse:0.26047	train-rmse:0.268998
# [17]	test-rmse:0.233023	train-rmse:0.242509
# [18]	test-rmse:0.213391	train-rmse:0.223632
# [19]	test-rmse:0.195425	train-rmse:0.206476
# [20]	test-rmse:0.184416	train-rmse:0.196297
# [21]	test-rmse:0.172241	train-rmse:0.184683
# [22]	test-rmse:0.166827	train-rmse:0.179605
# [23]	test-rmse:0.161192	train-rmse:0.17439
# [24]	test-rmse:0.153356	train-rmse:0.167081
# [25]	test-rmse:0.151314	train-rmse:0.164893
# [26]	test-rmse:0.146693	train-rmse:0.160114
# [27]	test-rmse:0.144878	train-rmse:0.158451
# [28]	test-rmse:0.143696	train-rmse:0.15718
# [29]	test-rmse:0.141219	train-rmse:0.154951
# [30]	test-rmse:0.138958	train-rmse:0.152569
# [31]	test-rmse:0.138087	train-rmse:0.151522
# [32]	test-rmse:0.136924	train-rmse:0.150365
# [33]	test-rmse:0.135883	train-rmse:0.149289
# [34]	test-rmse:0.134584	train-rmse:0.147738
# [35]	test-rmse:0.134133	train-rmse:0.147149
# [36]	test-rmse:0.132934	train-rmse:0.145619
# [37]	test-rmse:0.132358	train-rmse:0.144924
# [38]	test-rmse:0.131275	train-rmse:0.143923
# [39]	test-rmse:0.130173	train-rmse:0.142758
# [40]	test-rmse:0.129418	train-rmse:0.141799
# [41]	test-rmse:0.129128	train-rmse:0.141156
# [42]	test-rmse:0.128776	train-rmse:0.140652
# [43]	test-rmse:0.127585	train-rmse:0.139443
# [44]	test-rmse:0.127125	train-rmse:0.138788
# [45]	test-rmse:0.126453	train-rmse:0.137175
# [46]	test-rmse:0.126066	train-rmse:0.136499
# [47]	test-rmse:0.125495	train-rmse:0.135501
# [48]	test-rmse:0.124218	train-rmse:0.13436
# [49]	test-rmse:0.123838	train-rmse:0.134007
# [50]	test-rmse:0.123437	train-rmse:0.133184
# [51]	test-rmse:0.122702	train-rmse:0.131987
# [52]	test-rmse:0.121984	train-rmse:0.130984
# [53]	test-rmse:0.121696	train-rmse:0.1305
# [54]	test-rmse:0.121407	train-rmse:0.130239
# [55]	test-rmse:0.121287	train-rmse:0.130066
# [56]	test-rmse:0.120751	train-rmse:0.129481
# [57]	test-rmse:0.120646	train-rmse:0.129253
# [58]	test-rmse:0.120307	train-rmse:0.128847
# [59]	test-rmse:0.119736	train-rmse:0.128284
# [60]	test-rmse:0.119486	train-rmse:0.127772
# [61]	test-rmse:0.119235	train-rmse:0.127524
# [62]	test-rmse:0.119147	train-rmse:0.127181
# [63]	test-rmse:0.118788	train-rmse:0.126677
# [64]	test-rmse:0.118742	train-rmse:0.125773
# [65]	test-rmse:0.118335	train-rmse:0.125336
# [66]	test-rmse:0.118244	train-rmse:0.125247
# [67]	test-rmse:0.118059	train-rmse:0.12499
# [68]	test-rmse:0.118001	train-rmse:0.124918
# [69]	test-rmse:0.117895	train-rmse:0.124656
# [70]	test-rmse:0.117842	train-rmse:0.124426
# [71]	test-rmse:0.117718	train-rmse:0.124264
# [72]	test-rmse:0.117639	train-rmse:0.124046
# [73]	test-rmse:0.117206	train-rmse:0.123438
# [74]	test-rmse:0.116529	train-rmse:0.122406
# [75]	test-rmse:0.116505	train-rmse:0.122371
# [76]	test-rmse:0.116296	train-rmse:0.122003
# [77]	test-rmse:0.116084	train-rmse:0.121414
# [78]	test-rmse:0.115803	train-rmse:0.121029
# [79]	test-rmse:0.115775	train-rmse:0.120901
# [80]	test-rmse:0.115748	train-rmse:0.120702
# [81]	test-rmse:0.115362	train-rmse:0.120178
# [82]	test-rmse:0.114845	train-rmse:0.119672
# [83]	test-rmse:0.114786	train-rmse:0.119365
# [84]	test-rmse:0.114752	train-rmse:0.119058
# [85]	test-rmse:0.114611	train-rmse:0.118901
# [86]	test-rmse:0.114585	train-rmse:0.118792
# [87]	test-rmse:0.114513	train-rmse:0.118644
# [88]	test-rmse:0.114406	train-rmse:0.118358
# [89]	test-rmse:0.114317	train-rmse:0.118314
# [90]	test-rmse:0.114112	train-rmse:0.117976
# [91]	test-rmse:0.114047	train-rmse:0.117896
# [92]	test-rmse:0.113478	train-rmse:0.117401
# [93]	test-rmse:0.112886	train-rmse:0.116714
# [94]	test-rmse:0.112835	train-rmse:0.116565
# [95]	test-rmse:0.112785	train-rmse:0.116498
# [96]	test-rmse:0.112683	train-rmse:0.116387
# [97]	test-rmse:0.112681	train-rmse:0.116237
# [98]	test-rmse:0.112661	train-rmse:0.116194
# [99]	test-rmse:0.112565	train-rmse:0.115845
# [100]	test-rmse:0.112484	train-rmse:0.11572
# [101]	test-rmse:0.112185	train-rmse:0.11543
# [102]	test-rmse:0.112094	train-rmse:0.115327
# [103]	test-rmse:0.112084	train-rmse:0.115286
# [104]	test-rmse:0.11206	train-rmse:0.115109
# [105]	test-rmse:0.112041	train-rmse:0.115071
# [106]	test-rmse:0.111904	train-rmse:0.114872
# [107]	test-rmse:0.111859	train-rmse:0.114797
# [108]	test-rmse:0.111798	train-rmse:0.114428
# [109]	test-rmse:0.111727	train-rmse:0.114344
# [110]	test-rmse:0.1118	train-rmse:0.114143
# [111]	test-rmse:0.111788	train-rmse:0.113946
# [112]	test-rmse:0.111782	train-rmse:0.113842
# [113]	test-rmse:0.111759	train-rmse:0.113546
# [114]	test-rmse:0.111551	train-rmse:0.113272
# [115]	test-rmse:0.111498	train-rmse:0.113201
# [116]	test-rmse:0.111425	train-rmse:0.113003
# [117]	test-rmse:0.111366	train-rmse:0.112901
# [118]	test-rmse:0.111339	train-rmse:0.112814
# [119]	test-rmse:0.111142	train-rmse:0.11239
# [120]	test-rmse:0.110915	train-rmse:0.112042
# [121]	test-rmse:0.110981	train-rmse:0.111717
# [122]	test-rmse:0.110897	train-rmse:0.111346
# [123]	test-rmse:0.110876	train-rmse:0.111196
# [124]	test-rmse:0.110876	train-rmse:0.111171
# [125]	test-rmse:0.110703	train-rmse:0.110915
# [126]	test-rmse:0.110671	train-rmse:0.110473
# [127]	test-rmse:0.110664	train-rmse:0.11045
# [128]	test-rmse:0.110641	train-rmse:0.110265
# [129]	test-rmse:0.110402	train-rmse:0.109992
# [130]	test-rmse:0.110367	train-rmse:0.109938
# [131]	test-rmse:0.10998	train-rmse:0.109474
# [132]	test-rmse:0.109977	train-rmse:0.109446
# [133]	test-rmse:0.109976	train-rmse:0.10938
# [134]	test-rmse:0.109948	train-rmse:0.109267
# [135]	test-rmse:0.109922	train-rmse:0.109214
# [136]	test-rmse:0.10974	train-rmse:0.108867
# [137]	test-rmse:0.109823	train-rmse:0.108629
# [138]	test-rmse:0.109815	train-rmse:0.108616
# [139]	test-rmse:0.109737	train-rmse:0.108244
# [140]	test-rmse:0.109737	train-rmse:0.108228
# [141]	test-rmse:0.109715	train-rmse:0.10801
# [142]	test-rmse:0.109641	train-rmse:0.107926
# [143]	test-rmse:0.109517	train-rmse:0.107766
# [144]	test-rmse:0.109214	train-rmse:0.107377
# [145]	test-rmse:0.10873	train-rmse:0.106877
# [146]	test-rmse:0.108705	train-rmse:0.106702
# [147]	test-rmse:0.108655	train-rmse:0.106612
# [148]	test-rmse:0.108612	train-rmse:0.106546
# [149]	test-rmse:0.108607	train-rmse:0.106485
# [150]	test-rmse:0.108549	train-rmse:0.106187
# [151]	test-rmse:0.108504	train-rmse:0.106038
# [152]	test-rmse:0.108497	train-rmse:0.105934
# [153]	test-rmse:0.108332	train-rmse:0.105546
# [154]	test-rmse:0.108314	train-rmse:0.105484
# [155]	test-rmse:0.108253	train-rmse:0.105408
# [156]	test-rmse:0.10825	train-rmse:0.105381
# [157]	test-rmse:0.10823	train-rmse:0.105304
# [158]	test-rmse:0.108057	train-rmse:0.105063
# [159]	test-rmse:0.108041	train-rmse:0.105024
# [160]	test-rmse:0.10804	train-rmse:0.104943
# [161]	test-rmse:0.108024	train-rmse:0.10492
# [162]	test-rmse:0.108019	train-rmse:0.104892
# [163]	test-rmse:0.108013	train-rmse:0.104861
# [164]	test-rmse:0.107914	train-rmse:0.104732
# [165]	test-rmse:0.107881	train-rmse:0.10467
# [166]	test-rmse:0.107871	train-rmse:0.104504
# [167]	test-rmse:0.107848	train-rmse:0.10441
# [168]	test-rmse:0.107841	train-rmse:0.10428
# [169]	test-rmse:0.107831	train-rmse:0.104261
# [170]	test-rmse:0.107746	train-rmse:0.10416
# [171]	test-rmse:0.107616	train-rmse:0.103982
# [172]	test-rmse:0.107618	train-rmse:0.103969
# [173]	test-rmse:0.107609	train-rmse:0.103911
# [174]	test-rmse:0.107517	train-rmse:0.10364
# [175]	test-rmse:0.107448	train-rmse:0.103502
# [176]	test-rmse:0.107422	train-rmse:0.103426
# [177]	test-rmse:0.10743	train-rmse:0.103404
# [178]	test-rmse:0.107427	train-rmse:0.103399
# [179]	test-rmse:0.107425	train-rmse:0.103375
# [180]	test-rmse:0.107328	train-rmse:0.103084
# [181]	test-rmse:0.107314	train-rmse:0.103045
# [182]	test-rmse:0.107278	train-rmse:0.102989
# [183]	test-rmse:0.107237	train-rmse:0.10275
# [184]	test-rmse:0.107185	train-rmse:0.102569
# [185]	test-rmse:0.107164	train-rmse:0.102514
# [186]	test-rmse:0.106958	train-rmse:0.102283
# [187]	test-rmse:0.106957	train-rmse:0.102243
# [188]	test-rmse:0.106874	train-rmse:0.102137
# [189]	test-rmse:0.106865	train-rmse:0.102018
# [190]	test-rmse:0.106852	train-rmse:0.101868
# [191]	test-rmse:0.106811	train-rmse:0.101764
# [192]	test-rmse:0.106711	train-rmse:0.101642
# [193]	test-rmse:0.106718	train-rmse:0.101606
# [194]	test-rmse:0.106715	train-rmse:0.101542
# [195]	test-rmse:0.106721	train-rmse:0.101525
# [196]	test-rmse:0.106693	train-rmse:0.101316
# [197]	test-rmse:0.106652	train-rmse:0.101234
# [198]	test-rmse:0.106623	train-rmse:0.101158
# [199]	test-rmse:0.10658	train-rmse:0.101057

# %% [markdown]
# ### Validating

# %%
print("Validating")
train_probs = gbm.predict(xgb.DMatrix(X_test[features]))
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# Validating
# error 0.11904310564026153

# %% [markdown]
# RMSE

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="gain")
plt.title("XGBoost Feature Gain")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="weight")
plt.title("XGBoost Feature weight")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="cover")
plt.title("XGBoost Feature cover")
plt.show()

# %% [markdown]
# ### Predict on fake test set

# %%
train_probs = gbm.predict(xgb.DMatrix(test[features]))

# %%
test['_NumberOfSales'] = np.exp(gbm.predict(xgb.DMatrix(test[features])))-1
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## BIP Error

# %%
from BIP_error import get_BIP_error
error1 = get_BIP_error(test)
# Out:
# Number of regions identified: 11
# BIP total error: 0.044246179935774205

# %%
diff=test['NumberOfSales']-test['_NumberOfSales']

# %%
diff.head(15).T
# Out:
# 670    -212.747070
# 671    2070.460938
# 672    -356.118652
# 674    -473.026855
# 675   -1303.062988
# 677   -1848.073242
# 678   -2160.660156
# 679   -2172.970703
# 680   -1432.466309
# 681    -185.285156
# 682    -684.897461
# 684      27.769531
# 685     744.705566
# 686   -1181.346680
# 687    -648.809082
# dtype: float32

# %%
diff.mean()
# Out:
# -48.67221450805664

# %%
train_probs.shape
# Out:
# (36911,)

# %%
#test['predicted'] = pd.Series([train_probs], index=test.index)
#test['predicted']=train_probs

# %%
compare = test[['NumberOfSales','_NumberOfSales']]

# %% [markdown]
# ### Saving TEST

# %%
#test.to_csv('./dataset/XGB5_fake_test.csv', index=False)

# %%
error = rmspe(test['_NumberOfSales'].values, test['NumberOfSales'].values)
print('error', error)
# Out:
# error 0.19567676584967392

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 14893           5468     4305.241211
# 14894           6795     6959.092773
# 14896           7035     7389.159668
# 14897           5437     6403.018066
# 14898           5725     6050.510254
# 14899           5143     6049.540527
# 14900           5589     6637.783203
# 14901           7520     6460.241211
# 14903           3927     5377.758301
# 14904           3682     4539.054688
# 14905           3601     4638.782715
# 14906           3383     4436.059082
# 14907           4627     5022.581055
# 14908           7250     7006.212891
# 14910           7161     7441.831543
# 14911           6252     6416.639648
# 14912           5092     6531.960449
# 14913           6056     5689.226562
# 14914           6610     6966.796875
# 14915           6889     7077.340332
# 14917           7256     8062.583984
# 14918           5437     6403.018066
# 14919           5755     6056.093262
# 14920           5610     5707.767090
# 14921           5732     6456.145020
# 14922           6222     6517.634277
# 14924           4278     4527.405273
# 14925           3720     4467.176270
# 14926           4153     4432.691895
# 14927           3965     4455.226562
# ...              ...             ...
# 15646           7308     7395.322266
# 15647           6085     6616.064453
# 15648           5232     6430.136719
# 15649           5318     6200.655762
# 15650           4956     5668.588867
# 15651           5238     5253.640625
# 15653           4906     4981.914062
# 15654           4637     4571.033691
# 15655           4487     4837.208008
# 15656           4724     4565.151367
# 15657           5461     4947.613281
# 15658           5351     4935.000000
# 15660           6989     7063.906250
# 15661           5695     6337.270020
# 15662           5101     5912.131348
# 15663           5429     5501.579590
# 15664           5650     5873.942383
# 15665           5022     4743.868164
# 15667           4751     5049.423828
# 15668           4288     4191.178223
# 15669           4509     4163.782227
# 16340           5921     5533.435547
# 16341           6406     4903.753418
# 16342           3053     3037.427490
# 16344           5846     5972.910645
# 16345           4333     4316.352051
# 16347           9605     9796.506836
# 16349           7700     7960.709473
# 16350           6697     6996.283203
# 16351           6753     6617.623535
#
# [100 rows x 2 columns]

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 14893           5468     4305.241211
# 14894           6795     6959.092773
# 14896           7035     7389.159668
# 14897           5437     6403.018066
# 14898           5725     6050.510254
# 14899           5143     6049.540527
# 14900           5589     6637.783203
# 14901           7520     6460.241211
# 14903           3927     5377.758301
# 14904           3682     4539.054688
# 14905           3601     4638.782715
# 14906           3383     4436.059082
# 14907           4627     5022.581055
# 14908           7250     7006.212891
# 14910           7161     7441.831543
# 14911           6252     6416.639648
# 14912           5092     6531.960449
# 14913           6056     5689.226562
# 14914           6610     6966.796875
# 14915           6889     7077.340332
# 14917           7256     8062.583984
# 14918           5437     6403.018066
# 14919           5755     6056.093262
# 14920           5610     5707.767090
# 14921           5732     6456.145020
# 14922           6222     6517.634277
# 14924           4278     4527.405273
# 14925           3720     4467.176270
# 14926           4153     4432.691895
# 14927           3965     4455.226562
# ...              ...             ...
# 15646           7308     7395.322266
# 15647           6085     6616.064453
# 15648           5232     6430.136719
# 15649           5318     6200.655762
# 15650           4956     5668.588867
# 15651           5238     5253.640625
# 15653           4906     4981.914062
# 15654           4637     4571.033691
# 15655           4487     4837.208008
# 15656           4724     4565.151367
# 15657           5461     4947.613281
# 15658           5351     4935.000000
# 15660           6989     7063.906250
# 15661           5695     6337.270020
# 15662           5101     5912.131348
# 15663           5429     5501.579590
# 15664           5650     5873.942383
# 15665           5022     4743.868164
# 15667           4751     5049.423828
# 15668           4288     4191.178223
# 15669           4509     4163.782227
# 16340           5921     5533.435547
# 16341           6406     4903.753418
# 16342           3053     3037.427490
# 16344           5846     5972.910645
# 16345           4333     4316.352051
# 16347           9605     9796.506836
# 16349           7700     7960.709473
# 16350           6697     6996.283203
# 16351           6753     6617.623535
#
# [100 rows x 2 columns]

# %%
#REAL
start = 500
end = 600
import matplotlib.pyplot as plt

y = compare.iloc[start:end,0].values
x_coordinate = [ 1 * i for i in range(len(y)) ]
plt.plot(x_coordinate,y)
plt.show()

# %%
import matplotlib.pyplot as plt

yhat = compare.iloc[start:end:1].values
x_coordinate = [ 1 * i for i in range(len(yhat)) ]
plt.plot(x_coordinate,yhat)
plt.legend(['Real', 'Predicted'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
#import matplotlib as mpl

#mpl.style.use("default")


plt.plot(x_coordinate,y)
plt.plot(x_coordinate,yhat)
plt.legend(['Predicted', 'Real'], loc='upper left')
plt.show()

# %%
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-f3f3bea90e90> in <module>()
#       1 indices = train_probs < 0
#       2 train_probs[indices] = 0
# ----> 3 error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
#       4 print('error', error)
#
# <ipython-input-23-8df05da968cb> in rmspe(yhat, y)
#      11 def rmspe(yhat, y):
#      12     w = ToWeight(y)
# ---> 13     rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
#      14     return rmspe
#      15
#
# ValueError: operands could not be broadcast together with shapes (19853,) (36911,)

# %%
test_probs = gbm.predict(xgb.DMatrix(test[features]))
indices = test_probs < 0
test_probs[indices] = 0
submission = pd.DataFrame({"Id": test["Id"], "Sales": np.exp(test_probs) - 1})
submission.to_csv("xgboost_kscript_submission.csv", index=False)

# %%
Y = df.iloc[:, 3]

# %%
Y
