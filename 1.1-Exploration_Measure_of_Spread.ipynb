# %% [markdown]
# # Data exploration - Measure of Spread
#
# Analysis of the data spread.

# %%
from dataset_features import numerical, categorical

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":20,"axes.titlesize":30,"axes.labelsize":30})  

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./dataset/train.csv')

# Use only numerical attributes
df = df[numerical]
df.head()
# Out:
#    Region_AreaKM2  Mean_Dew_PointC  Max_VisibilityKm  WindDirDegrees  \
# 0            9643               -1              19.0              23
# 1            9643               -1              23.0              56
# 2            9643               -1              31.0              22
# 3            9643               -4              31.0             108
# 4            9643               -3              31.0              46
#
#    Min_Dew_PointC  Region_GDP  Max_Humidity  Mean_Sea_Level_PressurehPa  \
# 0              -2       17130           100                        1030
# 1              -2       17130            87                        1027
# 2              -3       17130            81                        1024
# 3              -6       17130            80                        1024
# 4              -6       17130            93                        1023
#
#    Min_Humidity  Min_TemperatureC         ...          \
# 0            70                 1         ...
# 1            58                 1         ...
# 2            55                 2         ...
# 3            25                -1         ...
# 4            48                -5         ...
#
#    Min_Sea_Level_PressurehPa  CloudCover  Max_Gust_SpeedKm_h  \
# 0                       1029         8.0                 NaN
# 1                       1025         8.0                 NaN
# 2                       1023         8.0                 NaN
# 3                       1022         6.0                 NaN
# 4                       1022         6.0                 NaN
#
#    Mean_Wind_SpeedKm_h  NumberOfSales  Mean_TemperatureC  NearestCompetitor  \
# 0                   16           5676                  1                326
# 1                   10           8111                  3                326
# 2                   10           8300                  3                326
# 3                   10           7154                  3                326
# 4                    5              0                  1                326
#
#    Precipitationmm  Mean_VisibilityKm  Max_Wind_SpeedKm_h
# 0              0.0               11.0                  21
# 1              0.0               13.0                  16
# 2              0.0               11.0                  23
# 3              0.0               15.0                  19
# 4              0.0               12.0                  16
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Min, Range, Max

# %%
min_range_max = pd.DataFrame({
        'min': df.min(),
        'range': df.max() - df.min(),
        'max': df.max()
    })

min_range_max[['min', 'range', 'max']]
# Out:
#                                min     range       max
# Region_AreaKM2               344.0  31877.00  32221.00
# Mean_Dew_PointC              -15.0     35.00     20.00
# Max_VisibilityKm               0.0     31.00     31.00
# WindDirDegrees                -1.0    361.00    360.00
# Min_Dew_PointC               -18.0     36.00     18.00
# Region_GDP                  9893.0  14038.00  23931.00
# Max_Humidity                  44.0     56.00    100.00
# Mean_Sea_Level_PressurehPa   974.0     66.00   1040.00
# Min_Humidity                  10.0     90.00    100.00
# Min_TemperatureC             -15.0     39.00     24.00
# NumberOfCustomers              0.0   2206.00   2206.00
# Max_Sea_Level_PressurehPa    976.0     67.00   1043.00
# Mean_Humidity                 30.0     70.00    100.00
# Region_PopulationK           816.0   7330.00   8146.00
# Max_Dew_PointC               -14.0     37.00     23.00
# Min_VisibilitykM               0.0     31.00     31.00
# Max_TemperatureC             -11.0     48.00     37.00
# Min_Sea_Level_PressurehPa    970.0     68.00   1038.00
# CloudCover                     0.0      8.00      8.00
# Max_Gust_SpeedKm_h            21.0     85.00    106.00
# Mean_Wind_SpeedKm_h            2.0     51.00     53.00
# NumberOfSales                  0.0  26641.00  26641.00
# Mean_TemperatureC            -13.0     43.00     30.00
# NearestCompetitor             47.0  85023.00  85070.00
# Precipitationmm                0.0     58.93     58.93
# Mean_VisibilityKm              0.0     31.00     31.00
# Max_Wind_SpeedKm_h             3.0     98.00    101.00

# %% [markdown]
# ### Numerical attributes variance

# %%
df.var(axis=0)
# Out:
# Region_AreaKM2                8.355226e+07
# Mean_Dew_PointC               3.459238e+01
# Max_VisibilityKm              8.408347e+01
# WindDirDegrees                1.034863e+04
# Min_Dew_PointC                3.491743e+01
# Region_GDP                    7.592369e+06
# Max_Humidity                  5.802462e+01
# Mean_Sea_Level_PressurehPa    6.825276e+01
# Min_Humidity                  3.718736e+02
# Min_TemperatureC              3.985388e+01
# NumberOfCustomers             3.454286e+04
# Max_Sea_Level_PressurehPa     6.377097e+01
# Mean_Humidity                 1.674368e+02
# Region_PopulationK            7.933909e+06
# Max_Dew_PointC                3.585976e+01
# Min_VisibilitykM              2.400584e+01
# Max_TemperatureC              6.717925e+01
# Min_Sea_Level_PressurehPa     7.567671e+01
# CloudCover                    2.942175e+00
# Max_Gust_SpeedKm_h            1.631170e+02
# Mean_Wind_SpeedKm_h           3.353604e+01
# NumberOfSales                 7.450882e+06
# Mean_TemperatureC             4.957803e+01
# NearestCompetitor             1.331187e+08
# Precipitationmm               6.924414e+00
# Mean_VisibilityKm             2.478432e+01
# Max_Wind_SpeedKm_h            7.613053e+01
# dtype: float64

# %%
'Min variance attribute', df.var().idxmin(), df.var().min()
# Out:
# ('Min variance attribute', 'CloudCover', 2.9421751394678517)

# %%
'Max variance attribute', df.var().idxmax(), df.var().max()
# Out:
# ('Max variance attribute', 'NearestCompetitor', 133118695.05287102)

# %% [markdown]
# ### Variance bar plots
#
# All the attributes

# %%
df.var(axis=0).plot(kind='bar')

# %% [markdown]
# Excluding __NearestCompetitor, Region_AreaKM2__

# %%
df1 = df.var(axis=0).drop(['NearestCompetitor', 'Region_AreaKM2'])
df1.plot(kind='bar')

# %% [markdown]
# Excluding *NearestCompetitor*, __Region_PopulationK, NumberOfSales, Region_GDP,__ *Region_AreaKM2*

# %%
df2 = df.var(axis=0).drop(['NearestCompetitor', 'Region_PopulationK', 'NumberOfSales', 'Region_GDP', 'Region_AreaKM2'])
df2.plot(kind='bar')

# %% [markdown]
# Excluding *NearestCompetitor, Region_PopulationK, NumberOfSales, __WindDirDegrees, NumberOfCustomers__, Region_GDP, Region_AreaKM2*

# %%
df2 = df.var(axis=0).drop(['NearestCompetitor', 'Region_PopulationK', 'NumberOfSales', 'WindDirDegrees', 'NumberOfCustomers', 'Region_GDP', 'Region_AreaKM2'])
df2.plot(kind='bar')

# %% [markdown]
# The above vertical bar plot excludes the 7 highest variance attributes and shows the variances of the remaining attributes.

# %% [markdown]
# ## Variance bar plot after normalization

# %%
df.shape
# Out:
# (523021, 27)

# %%
df.describe()
# Out:
#        Region_AreaKM2  Mean_Dew_PointC  Max_VisibilityKm  WindDirDegrees  \
# count   523021.000000    523021.000000     511683.000000   523021.000000
# mean     12381.265718         6.229677         23.560275      170.458096
# std       9140.692427         5.881529          9.169704      101.728193
# min        344.000000       -15.000000          0.000000       -1.000000
# 25%       7215.000000         2.000000         11.000000       75.000000
# 50%       9643.000000         7.000000         31.000000      191.000000
# 75%      15566.000000        11.000000         31.000000      250.000000
# max      32221.000000        20.000000         31.000000      360.000000
#
#        Min_Dew_PointC     Region_GDP   Max_Humidity  \
# count   523021.000000  523021.000000  523021.000000
# mean         3.737584   14050.547848      93.523316
# std          5.909098    2755.425404       7.617389
# min        -18.000000    9893.000000      44.000000
# 25%         -1.000000   11849.000000      90.000000
# 50%          4.000000   15017.000000      94.000000
# 75%          8.000000   15931.000000     100.000000
# max         18.000000   23931.000000     100.000000
#
#        Mean_Sea_Level_PressurehPa   Min_Humidity  Min_TemperatureC  \
# count               523021.000000  523021.000000     523021.000000
# mean                  1015.002422      51.375624          6.202315
# std                      8.261523      19.284023          6.312993
# min                    974.000000      10.000000        -15.000000
# 25%                   1010.000000      36.000000          1.000000
# 50%                   1015.000000      51.000000          7.000000
# 75%                   1020.000000      66.000000         11.000000
# max                   1040.000000     100.000000         24.000000
#
#               ...          Min_Sea_Level_PressurehPa     CloudCover  \
# count         ...                      523021.000000  481840.000000
# mean          ...                        1012.078435       5.568627
# std           ...                           8.699236       1.715277
# min           ...                         970.000000       0.000000
# 25%           ...                        1007.000000       5.000000
# 50%           ...                        1013.000000       6.000000
# 75%           ...                        1018.000000       7.000000
# max           ...                        1038.000000       8.000000
#
#        Max_Gust_SpeedKm_h  Mean_Wind_SpeedKm_h  NumberOfSales  \
# count       113074.000000        523021.000000  523021.000000
# mean            47.980782            11.724961    4057.377536
# std             12.771727             5.791031    2729.630381
# min             21.000000             2.000000       0.000000
# 25%             39.000000             8.000000    2573.000000
# 50%             47.000000            11.000000    4020.000000
# 75%             55.000000            14.000000    5538.000000
# max            106.000000            53.000000   26641.000000
#
#        Mean_TemperatureC  NearestCompetitor  Precipitationmm  \
# count      523021.000000       523021.00000    523021.000000
# mean           10.273205         8002.71122         0.808278
# std             7.041167        11537.70753         2.631428
# min           -13.000000           47.00000         0.000000
# 25%             4.000000         1057.00000         0.000000
# 50%            11.000000         3321.00000         0.000000
# 75%            16.000000         9673.00000         0.250000
# max            30.000000        85070.00000        58.930000
#
#        Mean_VisibilityKm  Max_Wind_SpeedKm_h
# count      511683.000000       523021.000000
# mean           12.151025           22.223437
# std             4.978385            8.725281
# min             0.000000            3.000000
# 25%            10.000000           14.000000
# 50%            11.000000           21.000000
# 75%            14.000000           26.000000
# max            31.000000          101.000000
#
# [8 rows x 27 columns]

# %%
df_norm = pd.DataFrame()

for column in numerical:
    df_norm[column] = (df[column] - df[column].mean()) / (df[column].max() - df[column].min())

df_norm.head()
# Out:
#    Region_AreaKM2  Mean_Dew_PointC  Max_VisibilityKm  WindDirDegrees  \
# 0       -0.085901        -0.206562         -0.147106       -0.408471
# 1       -0.085901        -0.206562         -0.018073       -0.317058
# 2       -0.085901        -0.206562          0.239991       -0.411241
# 3       -0.085901        -0.292276          0.239991       -0.173014
# 4       -0.085901        -0.263705          0.239991       -0.344759
#
#    Min_Dew_PointC  Region_GDP  Max_Humidity  Mean_Sea_Level_PressurehPa  \
# 0       -0.159377    0.219365      0.115655                    0.227236
# 1       -0.159377    0.219365     -0.116488                    0.181781
# 2       -0.187155    0.219365     -0.223631                    0.136327
# 3       -0.270488    0.219365     -0.241488                    0.136327
# 4       -0.270488    0.219365     -0.009345                    0.121175
#
#    Min_Humidity  Min_TemperatureC         ...          \
# 0      0.206938         -0.133393         ...
# 1      0.073604         -0.133393         ...
# 2      0.040271         -0.107752         ...
# 3     -0.293062         -0.184675         ...
# 4     -0.037507         -0.287239         ...
#
#    Min_Sea_Level_PressurehPa  CloudCover  Max_Gust_SpeedKm_h  \
# 0                   0.248847    0.303922                 NaN
# 1                   0.190023    0.303922                 NaN
# 2                   0.160611    0.303922                 NaN
# 3                   0.145905    0.053922                 NaN
# 4                   0.145905    0.053922                 NaN
#
#    Mean_Wind_SpeedKm_h  NumberOfSales  Mean_TemperatureC  NearestCompetitor  \
# 0             0.083824       0.060757          -0.215656           -0.09029
# 1            -0.033823       0.152157          -0.169144           -0.09029
# 2            -0.033823       0.159252          -0.169144           -0.09029
# 3            -0.033823       0.116235          -0.169144           -0.09029
# 4            -0.131862      -0.152298          -0.215656           -0.09029
#
#    Precipitationmm  Mean_VisibilityKm  Max_Wind_SpeedKm_h
# 0        -0.013716          -0.037130           -0.012484
# 1        -0.013716           0.027386           -0.063504
# 2        -0.013716          -0.037130            0.007924
# 3        -0.013716           0.091902           -0.032892
# 4        -0.013716          -0.004872           -0.063504
#
# [5 rows x 27 columns]

# %%
df_norm.var(axis=0).plot(kind='bar')

# %% [markdown]
# # Box plots

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
sns.boxplot(x="class", y="age", data=df[numerical_variables_with_class])
