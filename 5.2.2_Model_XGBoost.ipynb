# %% [markdown]
# # XGBoost model

# %%
import pandas as pd
import numpy as np
#from sklearn import cross_validation
from sklearn.model_selection import cross_validate
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import validation_curve

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['figure.figsize'] = [20.0,8.0]
plt.rcParams['figure.dpi']=80

import modify_dataset as md

# %%
#Common error function to minimize: Root Mean Square Percentage Error
#We will have to integrate our loss function with xgboost

def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    return w


def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean( w * (y - yhat)**2 ))
    return rmspe


def rmspe_xg(yhat, y):
    # y = y.values
    y = y.get_label()
    y = np.exp(y) - 1
    yhat = np.exp(yhat) - 1
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat)**2))
    return "rmspe", rmspe

# %%
df = pd.read_csv("dataset/preprocessed_PCA_train.csv")

# %%
df = df.drop(['NumberOfCustomers'], axis=1)
#df = df.drop(['Region','Events'], axis=1)
# I could leave events

# %%
df = df[df.IsOpen == 1]

# %%
#for now let's drop unusable categorical vars
df = df.drop(['StoreType','AssortmentType','Events'], axis=1)

# %%
#only for pca
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head(20).T
# Out:
#                                       0            1            2   \
# StoreID                             1000         1000         1000
# Date                          01/03/2016   02/03/2016   04/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5676         8111         8300
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             8            8            8
# Max_VisibilityKm                       0            1            2
# Min_VisibilitykM                       0            1            2
# WindDirDegrees                        23           56           22
# D_Day                                  1            2            4
# D_DayOfYear                           61           62           64
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            1            2            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# Events_Fog                             0            0            0
# Events_Hail                            0            0            0
# Events_Rain                            1            0            1
# Events_Snow                            1            1            0
# Events_Thunderstorm                    0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# p1                            0.00256786   0.00240132   0.00245896
# p2                            2.9667e-08 -0.000153601 -0.000126179
# p3                          -6.82637e-05  -0.00061158 -0.000313962
# p4                            0.00120964   0.00110584   0.00115681
# p5                          -0.000465953  0.000105397   0.00019508
# p6                          -0.000427374 -0.000473368  -0.00038466
# p7                          -8.55136e-06  0.000161448  0.000475247
# p8                           4.02821e-05 -9.16558e-05  7.71741e-05
# p9                          -9.36498e-05  1.11881e-05 -3.69309e-05
#
#                                       3            5            6   \
# StoreID                             1000         1000         1000
# Date                          05/03/2016   07/03/2016   08/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       7154        10110         9019
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            0            0
# Max_VisibilityKm                       3            5            6
# Min_VisibilitykM                       3            5            6
# WindDirDegrees                       108           68           62
# D_Day                                  5            7            8
# D_DayOfYear                           65           67           68
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# Events_Fog                             0            0            0
# Events_Hail                            0            0            0
# Events_Rain                            0            0            0
# Events_Snow                            0            0            0
# Events_Thunderstorm                    0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# p1                            0.00316316   0.00281737   0.00254385
# p2                          -0.000195833 -0.000194517 -0.000319153
# p3                          -0.000320068 -0.000148329 -0.000689802
# p4                            0.00113729    0.0011692   0.00107086
# p5                            0.00124732   0.00105726   0.00131133
# p6                           -0.00039246 -8.44977e-06 -0.000127111
# p7                           0.000195072  0.000150318 -0.000111131
# p8                          -0.000204222  -0.00048804 -0.000388148
# p9                          -5.80845e-05  1.24368e-06  9.56005e-05
#
#                                       7            8            9   \
# StoreID                             1000         1000         1000
# Date                          09/03/2016   10/03/2016   11/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          1            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       8804         7823         7989
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            7            7
# Max_VisibilityKm                       7            8            9
# Min_VisibilitykM                       7            8            9
# WindDirDegrees                        53           54           30
# D_Day                                  9           10           11
# D_DayOfYear                           69           70           71
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# Events_Fog                             0            0            0
# Events_Hail                            0            0            0
# Events_Rain                            0            1            1
# Events_Snow                            0            0            0
# Events_Thunderstorm                    0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# p1                            0.00198786  0.000610924 -0.000359253
# p2                          -0.000349151 -0.000544455 -0.000286752
# p3                          -0.000473437 -0.000724353 -0.000456425
# p4                            0.00111113   0.00107004   0.00112943
# p5                            0.00113658   0.00110311  0.000326031
# p6                           2.99142e-06 -0.000249045 -0.000262383
# p7                          -0.000243372  5.24386e-05  -0.00024594
# p8                          -0.000422646  0.000236369 -0.000227771
# p9                           6.15779e-05 -5.69163e-05 -0.000102025
#
#                                       10           12           13  \
# StoreID                             1000         1000         1000
# Date                          12/03/2016   14/03/2016   15/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       5895         6348         4738
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             6            7            7
# Max_VisibilityKm                      10           12           13
# Min_VisibilitykM                      10           12           13
# WindDirDegrees                       202           26           26
# D_Day                                 12           14           15
# D_DayOfYear                           72           74           75
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# Events_Fog                             0            0            1
# Events_Hail                            0            0            0
# Events_Rain                            1            1            1
# Events_Snow                            0            1            1
# Events_Thunderstorm                    0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# p1                          -0.000137931   0.00336352   0.00376318
# p2                          -0.000383229  9.68919e-05   0.00280398
# p3                          -0.000154321  0.000303945  0.000399078
# p4                            0.00119089   0.00126831   0.00130156
# p5                          -0.000270337 -0.000131591 -0.000413172
# p6                           0.000251084 -0.000138896 -0.000306542
# p7                           0.000130323 -4.10774e-05  -0.00022291
# p8                          -5.59789e-05  5.52573e-05 -1.38744e-05
# p9                          -0.000177625 -0.000172529  1.87359e-05
#
#                                       14           15           16  \
# StoreID                             1000         1000         1000
# Date                          16/03/2016   17/03/2016   18/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            0            0
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6014         6087         6962
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             5            4            2
# Max_VisibilityKm                      14           15           16
# Min_VisibilitykM                      14           15           16
# WindDirDegrees                        27          272          218
# D_Day                                 16           17           18
# D_DayOfYear                           76           77           78
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            2            3            4
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# Events_Fog                             0            0            0
# Events_Hail                            0            0            0
# Events_Rain                            0            0            0
# Events_Snow                            1            1            1
# Events_Thunderstorm                    0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# p1                            0.00470578   0.00503184   0.00503463
# p2                           9.63001e-05  0.000349739   5.2813e-05
# p3                          -0.000225438  -0.00102648 -0.000491436
# p4                            0.00116104   0.00102003   0.00110717
# p5                           0.000759687  0.000908353   0.00123393
# p6                          -0.000310039  0.000724728  -0.00012345
# p7                           9.85213e-05  5.07888e-05  5.95499e-05
# p8                          -0.000225986  0.000239829 -0.000155689
# p9                          -0.000147008  4.67937e-05  7.74693e-06
#
#                                       17           19           20  \
# StoreID                             1000         1000         1000
# Date                          19/03/2016   21/03/2016   22/03/2016
# IsHoliday                              0            0            0
# IsOpen                                 1            1            1
# HasPromotions                          0            1            1
# NearestCompetitor                    326          326          326
# Region                                 7            7            7
# NumberOfSales                       6618         9183         8155
# Region_AreaKM2                      9643         9643         9643
# Region_GDP                         17130        17130        17130
# Region_PopulationK                  2770         2770         2770
# CloudCover                             0            6            4
# Max_VisibilityKm                      17           19           20
# Min_VisibilitykM                      17           19           20
# WindDirDegrees                       138          190          211
# D_Day                                 19           21           22
# D_DayOfYear                           79           81           82
# D_Month                                3            3            3
# D_Year                              2016         2016         2016
# D_DayOfweek                            5            0            1
# StoreType_SuperMarket                  0            0            0
# StoreType_HyperMarket                  1            1            1
# StoreType_StandardMarket               0            0            0
# StoreType_ShoppingCenter               0            0            0
# AssortmentType_General                 1            1            1
# AssortmentType_WithNFDept              0            0            0
# AssortmentType_WithFishDept            0            0            0
# Events_Fog                             0            1            1
# Events_Hail                            0            0            0
# Events_Rain                            0            0            1
# Events_Snow                            0            0            0
# Events_Thunderstorm                    0            0            0
# MeanStoreSales                   6296.18      6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26      3906.26
# p1                            0.00422012   0.00195232   0.00213477
# p2                          -0.000181445 -0.000281797  -8.6691e-05
# p3                          -0.000331251 -0.000578328  0.000190708
# p4                             0.0011212   0.00110015   0.00124403
# p5                            0.00218009   0.00071595  8.32562e-05
# p6                           -0.00034211  6.79421e-05  0.000759295
# p7                           0.000646523 -0.000321805  0.000153544
# p8                           0.000194666  0.000421176 -0.000137665
# p9                           0.000111134 -0.000568984 -0.000144816
#
#                                       21           22
# StoreID                             1000         1000
# Date                          23/03/2016   24/03/2016
# IsHoliday                              0            0
# IsOpen                                 1            1
# HasPromotions                          1            1
# NearestCompetitor                    326          326
# Region                                 7            7
# NumberOfSales                       7109         8041
# Region_AreaKM2                      9643         9643
# Region_GDP                         17130        17130
# Region_PopulationK                  2770         2770
# CloudCover                             6            6
# Max_VisibilityKm                      21           22
# Min_VisibilitykM                      21           22
# WindDirDegrees                       191          331
# D_Day                                 23           24
# D_DayOfYear                           83           84
# D_Month                                3            3
# D_Year                              2016         2016
# D_DayOfweek                            2            3
# StoreType_SuperMarket                  0            0
# StoreType_HyperMarket                  1            1
# StoreType_StandardMarket               0            0
# StoreType_ShoppingCenter               0            0
# AssortmentType_General                 1            1
# AssortmentType_WithNFDept              0            0
# AssortmentType_WithFishDept            0            0
# Events_Fog                             0            0
# Events_Hail                            0            0
# Events_Rain                            1            1
# Events_Snow                            0            1
# Events_Thunderstorm                    0            0
# MeanStoreSales                   6296.18      6296.18
# MeanRegionSales                  3906.26      3906.26
# p1                            0.00125034   0.00267307
# p2                            0.00233751 -0.000124056
# p3                          -0.000319565 -0.000297937
# p4                            0.00116553   0.00115612
# p5                           0.000258545  0.000373992
# p6                           0.000530807 -0.000360019
# p7                           0.000311733  0.000270043
# p8                           0.000143669   9.3407e-05
# p9                          -3.97729e-05 -2.82993e-05

# %%
df.shape
# Out:
# (433958, 43)

# %%
train = md.get_fake_train(df)

# %%
train.shape
# Out:
# (397047, 43)

# %%
test = md.get_fake_test(df)
test.shape
# Out:
# (36911, 43)

# %%
#print("Load the training, test and store data using pandas")
#train = pd.read_csv("train.csv",low_memory=False)
#test = pd.read_csv("test.csv")
#store = pd.read_csv("store.csv")

# %% [markdown]
# ### Selecting predictive features

# %%
features = list(train.columns.values)
features.remove('NumberOfSales')
features.remove('StoreID')
features.remove('Date')
features.remove('IsOpen')
#features.remove('Region')
#features.remove('Region_GDP')
#features.remove('Max_Dew_PointC')
#features.remove('Min_Dew_PointC')
#features.remove('Max_Wind_SpeedKm_h')
#features.remove('Max_VisibilityKm')
#features.remove('IsOpen')
#features.remove('Min_Sea_Level_PressurehPa')
#features.remove('Precipitationmm')
#features.remove('Mean_Dew_PointC')
#features.remove('Min_TemperatureC')
print("features")

print(features)
# Out:
# features
# ['IsHoliday', 'HasPromotions', 'NearestCompetitor', 'Region', 'Region_AreaKM2', 'Region_GDP', 'Region_PopulationK', 'CloudCover', 'Max_VisibilityKm', 'Min_VisibilitykM', 'WindDirDegrees', 'D_Day', 'D_DayOfYear', 'D_Month', 'D_Year', 'D_DayOfweek', 'StoreType_SuperMarket', 'StoreType_HyperMarket', 'StoreType_StandardMarket', 'StoreType_ShoppingCenter', 'AssortmentType_General', 'AssortmentType_WithNFDept', 'AssortmentType_WithFishDept', 'Events_Fog', 'Events_Hail', 'Events_Rain', 'Events_Snow', 'Events_Thunderstorm', 'MeanStoreSales', 'MeanRegionSales', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9']

# %%
features.remove('p6')
features.remove('p3')
features.remove('p7')
features.remove('p9')
features.remove('Events_Thunderstorm')
features.remove('Events_Fog')

# %%
params = {"objective": "reg:linear",
          "eta": 0.2,
          "max_depth": 8,
          "subsample": 1.0,
          "colsample_bytree": 0.3, #0.3
          "silent": 1,
          "nthread":-1,
          #added as a test
          "eval_metric": "rmse",
          #"gamma": 2  #added as a test
          }

#reg_alpha 
#reg_lambda
num_trees = 100 #400

# %%
#split in train and test (not real test which is called test and is the fake test provided by md)
X_train, X_test = train_test_split(train, test_size=0.05)
#X_train, X_test = train.head(len(train) - val_size), train.tail(val_size)

# %%
dtrain = xgb.DMatrix(X_train[features], np.log(X_train["NumberOfSales"] + 1))
dvalid = xgb.DMatrix(X_test[features], np.log(X_test["NumberOfSales"] + 1))
#dtest = xgb.DMatrix(test[features])

# %%
X_train.shape
# Out:
# (377194, 43)

# %%
X_test.shape
# Out:
# (19853, 43)

# %%
#watchlist = [(dvalid, 'test'), (dtrain, 'train')]
#gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, feval=rmspe_xg, verbose_eval=True)

# %%
watchlist = [(dvalid, 'test'), (dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=20, verbose_eval=True)
# Out:
# [0]	test-rmse:6.33109	train-rmse:6.33709
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 20 rounds.
# [1]	test-rmse:5.06673	train-rmse:5.07236
# [2]	test-rmse:4.05782	train-rmse:4.06343
# [3]	test-rmse:3.25183	train-rmse:3.25758
# [4]	test-rmse:2.60844	train-rmse:2.61422
# [5]	test-rmse:2.09339	train-rmse:2.09928
# [6]	test-rmse:1.68419	train-rmse:1.68985
# [7]	test-rmse:1.358	train-rmse:1.36395
# [8]	test-rmse:1.09993	train-rmse:1.10613
# [9]	test-rmse:0.893565	train-rmse:0.900027
# [10]	test-rmse:0.73249	train-rmse:0.739223
# [11]	test-rmse:0.598163	train-rmse:0.60532
# [12]	test-rmse:0.493259	train-rmse:0.501142
# [13]	test-rmse:0.41387	train-rmse:0.422604
# [14]	test-rmse:0.357055	train-rmse:0.366584
# [15]	test-rmse:0.309193	train-rmse:0.319601
# [16]	test-rmse:0.275923	train-rmse:0.287027
# [17]	test-rmse:0.2524	train-rmse:0.2638
# [18]	test-rmse:0.235704	train-rmse:0.247678
# [19]	test-rmse:0.214261	train-rmse:0.226707
# [20]	test-rmse:0.205525	train-rmse:0.217866
# [21]	test-rmse:0.19578	train-rmse:0.208492
# [22]	test-rmse:0.188703	train-rmse:0.201729
# [23]	test-rmse:0.182878	train-rmse:0.196092
# [24]	test-rmse:0.179414	train-rmse:0.192715
# [25]	test-rmse:0.174958	train-rmse:0.188491
# [26]	test-rmse:0.17214	train-rmse:0.185834
# [27]	test-rmse:0.170156	train-rmse:0.183592
# [28]	test-rmse:0.161422	train-rmse:0.175424
# [29]	test-rmse:0.153769	train-rmse:0.168387
# [30]	test-rmse:0.152819	train-rmse:0.167428
# [31]	test-rmse:0.151543	train-rmse:0.166102
# [32]	test-rmse:0.151052	train-rmse:0.165395
# [33]	test-rmse:0.150251	train-rmse:0.164567
# [34]	test-rmse:0.149724	train-rmse:0.163981
# [35]	test-rmse:0.148661	train-rmse:0.16286
# [36]	test-rmse:0.143245	train-rmse:0.158008
# [37]	test-rmse:0.141999	train-rmse:0.156875
# [38]	test-rmse:0.140996	train-rmse:0.155806
# [39]	test-rmse:0.140446	train-rmse:0.155004
# [40]	test-rmse:0.137195	train-rmse:0.152028
# [41]	test-rmse:0.136124	train-rmse:0.150889
# [42]	test-rmse:0.133628	train-rmse:0.148584
# [43]	test-rmse:0.133434	train-rmse:0.148115
# [44]	test-rmse:0.132917	train-rmse:0.14755
# [45]	test-rmse:0.132597	train-rmse:0.147209
# [46]	test-rmse:0.132222	train-rmse:0.14648
# [47]	test-rmse:0.130434	train-rmse:0.144776
# [48]	test-rmse:0.130109	train-rmse:0.144227
# [49]	test-rmse:0.12907	train-rmse:0.142905
# [50]	test-rmse:0.128917	train-rmse:0.142494
# [51]	test-rmse:0.128633	train-rmse:0.142037
# [52]	test-rmse:0.127716	train-rmse:0.141199
# [53]	test-rmse:0.126989	train-rmse:0.140481
# [54]	test-rmse:0.124375	train-rmse:0.138166
# [55]	test-rmse:0.124031	train-rmse:0.137721
# [56]	test-rmse:0.122219	train-rmse:0.135971
# [57]	test-rmse:0.121964	train-rmse:0.135667
# [58]	test-rmse:0.12192	train-rmse:0.135378
# [59]	test-rmse:0.12136	train-rmse:0.133927
# [60]	test-rmse:0.120651	train-rmse:0.133282
# [61]	test-rmse:0.120326	train-rmse:0.132938
# [62]	test-rmse:0.119666	train-rmse:0.131644
# [63]	test-rmse:0.118813	train-rmse:0.130545
# [64]	test-rmse:0.118065	train-rmse:0.12983
# [65]	test-rmse:0.117625	train-rmse:0.129418
# [66]	test-rmse:0.117487	train-rmse:0.128934
# [67]	test-rmse:0.117394	train-rmse:0.12875
# [68]	test-rmse:0.117202	train-rmse:0.128428
# [69]	test-rmse:0.117074	train-rmse:0.127853
# [70]	test-rmse:0.116965	train-rmse:0.127707
# [71]	test-rmse:0.116875	train-rmse:0.127587
# [72]	test-rmse:0.116844	train-rmse:0.127465
# [73]	test-rmse:0.11664	train-rmse:0.127023
# [74]	test-rmse:0.116085	train-rmse:0.126281
# [75]	test-rmse:0.115284	train-rmse:0.125538
# [76]	test-rmse:0.115148	train-rmse:0.125242
# [77]	test-rmse:0.114454	train-rmse:0.124409
# [78]	test-rmse:0.114235	train-rmse:0.12389
# [79]	test-rmse:0.114032	train-rmse:0.123631
# [80]	test-rmse:0.113889	train-rmse:0.123345
# [81]	test-rmse:0.113695	train-rmse:0.123103
# [82]	test-rmse:0.113397	train-rmse:0.122652
# [83]	test-rmse:0.113317	train-rmse:0.122576
# [84]	test-rmse:0.113086	train-rmse:0.122277
# [85]	test-rmse:0.112208	train-rmse:0.121305
# [86]	test-rmse:0.111573	train-rmse:0.120509
# [87]	test-rmse:0.11141	train-rmse:0.120125
# [88]	test-rmse:0.111325	train-rmse:0.120013
# [89]	test-rmse:0.111133	train-rmse:0.119621
# [90]	test-rmse:0.110902	train-rmse:0.119189
# [91]	test-rmse:0.110797	train-rmse:0.118979
# [92]	test-rmse:0.110641	train-rmse:0.118348
# [93]	test-rmse:0.11048	train-rmse:0.118095
# [94]	test-rmse:0.110376	train-rmse:0.117856
# [95]	test-rmse:0.110091	train-rmse:0.117505
# [96]	test-rmse:0.109984	train-rmse:0.117366
# [97]	test-rmse:0.109924	train-rmse:0.11731
# [98]	test-rmse:0.109848	train-rmse:0.117073
# [99]	test-rmse:0.109788	train-rmse:0.117002

# %% [markdown]
# ### Validating

# %%
print("Validating")
train_probs = gbm.predict(xgb.DMatrix(X_test[features]))
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)
# Out:
# Validating
# error 0.11481790005128341

# %% [markdown]
# RMSE

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="gain")
plt.title("XGBoost Feature Gain")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="weight")
plt.title("XGBoost Feature weight")
plt.show()

# %%
# # Feature importance XGB for all features 
from xgboost import plot_importance
plot_importance(gbm, importance_type="cover")
plt.title("XGBoost Feature cover")
plt.show()

# %% [markdown]
# ### Predict on fake test set

# %%
train_probs = gbm.predict(xgb.DMatrix(test[features]))

# %%
test['_NumberOfSales'] = np.exp(gbm.predict(xgb.DMatrix(test[features])))-1
# Out:
# C:\Users\Mirko\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## BIP Error

# %%
from BIP_error import get_BIP_error
error1 = get_BIP_error(test)
# Out:
# Number of regions identified: 11
# BIP total error: 0.04561501227291726

# %%
diff=test['NumberOfSales']-test['_NumberOfSales']

# %%
diff.head(15).T
# Out:
# 343   -1020.562500
# 344   -1001.001465
# 345     766.709473
# 346    1024.638672
# 347    -330.423629
# 348     563.083984
# 349     496.740234
# 350    -157.377930
# 351       9.276855
# 352    -438.596680
# 353    -846.928223
# 354    -334.380172
# 355   -1159.650391
# 356    -784.121582
# 357    -883.473633
# dtype: float64

# %%
diff.mean()
# Out:
# 105.68320384653046

# %%
train_probs.shape
# Out:
# (45689,)

# %%
#test['predicted'] = pd.Series([train_probs], index=test.index)
#test['predicted']=train_probs

# %%
compare = test[['NumberOfSales','_NumberOfSales']]

# %% [markdown]
# ### Saving TEST

# %%
#test.to_csv('./dataset/XGB5_fake_test.csv', index=False)

# %%
error = rmspe(test['_NumberOfSales'].values, test['NumberOfSales'].values)
print('error', error)
# Out:
# error 0.1906332633043559

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 11847    3674.000000     2806.333984
# 11848    3758.073991     3694.969727
# 11849    3468.000000     3293.965820
# 11850    2836.000000     2913.733887
# 11851    2816.000000     3009.757080
# 11852    2919.000000     3098.549072
# 11853    4054.000000     3707.348145
# 11854    3793.000000     2729.045654
# 11855    3758.073991     3996.481689
# 11856    6245.000000     5123.181641
# 11857    3191.000000     4264.714844
# 11858    3431.000000     4473.645020
# 11859    3681.000000     4093.344238
# 11860    4626.000000     4180.628906
# 11861    3650.000000     2925.469727
# 11862    3758.073991     3811.747070
# 11863    2748.000000     3248.275635
# 11864    2664.000000     3175.477295
# 11865    2864.000000     3201.660889
# 11866    2351.000000     3216.345947
# 11867    3379.000000     3466.634521
# 11868    3599.000000     2935.245850
# 11869    3758.073991     3585.974365
# 11870    5168.000000     4931.042969
# 11871    4550.000000     4515.290527
# 11872    5036.000000     4033.320801
# 11873    4835.000000     4439.411621
# 11874    3758.073991     3791.229248
# 11875    4863.000000     2832.898193
# 11876    3758.073991     3704.608398
# ...              ...             ...
# 12401    4791.000000     4327.615234
# 12402    4136.000000     3469.248047
# 12403    3624.000000     3680.532471
# 12404    3508.000000     3355.372559
# 12405    3573.000000     3330.098145
# 12406    2097.000000     2262.837891
# 12407    3132.452736     3175.028809
# 12408    2694.000000     2626.141113
# 12409    2709.000000     2462.757812
# 12410    2697.000000     2563.056152
# 12411    3304.000000     2619.400146
# 12412    3174.000000     2686.344727
# 12413    2054.000000     2143.721436
# 12414    3132.452736     3039.421875
# 12415    5370.000000     4247.180664
# 12416    3949.000000     3648.776367
# 12417    3926.000000     3248.920166
# 12418    3792.000000     3536.568848
# 12419    3132.452736     3147.113770
# 12420    3086.000000     2047.035156
# 12421    3132.452736     3041.159180
# 12422    3132.452736     3196.295898
# 12423    2948.000000     2437.284180
# 12424    2547.000000     2196.377197
# 12425    2376.000000     2146.318604
# 12426    2699.000000     2435.259521
# 12427    1911.000000     2060.230957
# 12428    3132.452736     3122.296143
# 13097    2654.000000     3015.136963
# 13098    2915.000000     3510.803955
#
# [100 rows x 2 columns]

# %%
compare[1000:1100]
# Out:
#        NumberOfSales  _NumberOfSales
# 11847    3674.000000     2922.143555
# 11848    3758.073991     3691.728271
# 11849    3468.000000     3240.204102
# 11850    2836.000000     2986.788574
# 11851    2816.000000     3042.273438
# 11852    2919.000000     3069.326172
# 11853    4054.000000     3740.238281
# 11854    3793.000000     2866.475586
# 11855    3758.073991     3973.737549
# 11856    6245.000000     4872.062988
# 11857    3191.000000     4238.155762
# 11858    3431.000000     4264.840820
# 11859    3681.000000     4214.491211
# 11860    4626.000000     4178.611328
# 11861    3650.000000     3009.538818
# 11862    3758.073991     3792.574707
# 11863    2748.000000     3477.631104
# 11864    2664.000000     3448.200928
# 11865    2864.000000     3143.962891
# 11866    2351.000000     3149.735840
# 11867    3379.000000     3511.691650
# 11868    3599.000000     3005.109131
# 11869    3758.073991     3740.527100
# 11870    5168.000000     4652.839844
# 11871    4550.000000     4222.124512
# 11872    5036.000000     3889.862061
# 11873    4835.000000     4210.689941
# 11874    3758.073991     3836.816406
# 11875    4863.000000     2772.175049
# 11876    3758.073991     3615.014160
# ...              ...             ...
# 12401    4791.000000     5105.351562
# 12402    4136.000000     4045.149658
# 12403    3624.000000     4088.867920
# 12404    3508.000000     3795.434082
# 12405    3573.000000     3473.831299
# 12406    2097.000000     2297.841309
# 12407    3132.452736     3244.788330
# 12408    2694.000000     2942.511719
# 12409    2709.000000     2515.723877
# 12410    2697.000000     2546.191650
# 12411    3304.000000     2754.724854
# 12412    3174.000000     2558.312988
# 12413    2054.000000     2070.969238
# 12414    3132.452736     3054.875000
# 12415    5370.000000     4123.980957
# 12416    3949.000000     3806.550781
# 12417    3926.000000     3225.659424
# 12418    3792.000000     3712.593018
# 12419    3132.452736     3186.629395
# 12420    3086.000000     1934.445557
# 12421    3132.452736     2984.988525
# 12422    3132.452736     3069.701172
# 12423    2948.000000     2574.051514
# 12424    2547.000000     2517.833252
# 12425    2376.000000     2506.645020
# 12426    2699.000000     2396.780029
# 12427    1911.000000     2034.196533
# 12428    3132.452736     3153.728760
# 13097    2654.000000     3192.657227
# 13098    2915.000000     3409.847412
#
# [100 rows x 2 columns]

# %%
#REAL
start = 500
end = 600
import matplotlib.pyplot as plt

y = compare.iloc[start:end,0].values
x_coordinate = [ 1 * i for i in range(len(y)) ]
plt.plot(x_coordinate,y)
plt.show()

# %%
import matplotlib.pyplot as plt

yhat = compare.iloc[start:end:1].values
x_coordinate = [ 1 * i for i in range(len(yhat)) ]
plt.plot(x_coordinate,yhat)
plt.legend(['Real', 'Predicted'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
#import matplotlib as mpl

#mpl.style.use("default")


plt.plot(x_coordinate,y)
plt.plot(x_coordinate,yhat)
plt.legend(['Predicted', 'Real'], loc='upper left')
plt.show()

# %%
indices = train_probs < 0
train_probs[indices] = 0
error = rmspe(np.exp(train_probs) - 1, X_test['NumberOfSales'].values)
print('error', error)

# %%
test_probs = gbm.predict(xgb.DMatrix(test[features]))
indices = test_probs < 0
test_probs[indices] = 0
submission = pd.DataFrame({"Id": test["Id"], "Sales": np.exp(test_probs) - 1})
submission.to_csv("xgboost_kscript_submission.csv", index=False)

# %%
Y = df.iloc[:, 3]

# %%
Y
