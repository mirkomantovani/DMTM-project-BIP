# %% [markdown]
# Process to add a column with a processed value.

# %% [markdown]
# M = average(NumberOfSales)
# sales_normlz = (NumberOfSales-M)/M

# %%
from dataset_features import numerical
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./dataset/train.csv')
# reduce dataset size to speed up computation

df
# Out:
#         StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 0          1000  01/03/2016          0       1              0  Hyper Market
# 1          1000  02/03/2016          0       1              0  Hyper Market
# 2          1000  04/03/2016          0       1              0  Hyper Market
# 3          1000  05/03/2016          0       1              0  Hyper Market
# 4          1000  06/03/2016          0       0              0  Hyper Market
# 5          1000  07/03/2016          0       1              1  Hyper Market
# 6          1000  08/03/2016          0       1              1  Hyper Market
# 7          1000  09/03/2016          0       1              1  Hyper Market
# 8          1000  10/03/2016          0       1              1  Hyper Market
# 9          1000  11/03/2016          0       1              1  Hyper Market
# 10         1000  12/03/2016          0       1              0  Hyper Market
# ...

# %%
df = df[numerical]
df.head()
# Out:
#    Max_Humidity  CloudCover  Region_PopulationK  NumberOfCustomers  \
# 0           100         8.0                2770                495
# 1            87         8.0                2770                608
# 2            81         8.0                2770                665
# 3            80         6.0                2770                630
# 4            93         6.0                2770                  0
#
#    Max_Sea_Level_PressurehPa  Mean_Sea_Level_PressurehPa  Min_Dew_PointC  \
# 0                       1032                        1030              -2
# 1                       1030                        1027              -2
# 2                       1026                        1024              -3
# 3                       1027                        1024              -6
# 4                       1025                        1023              -6
#
#    NumberOfSales  Max_TemperatureC  Min_Sea_Level_PressurehPa  \
# ...

# %%
## let's take some stores

frames = [df1, df2, df3]

In [5]: result = pd.concat(frames)

# %%
df.describe()
# Out:
#        Max_Humidity  CloudCover  Region_PopulationK  NumberOfCustomers  \
# count    100.000000   96.000000               100.0         100.000000
# mean      88.850000    5.583333              2770.0         501.410000
# std       12.669358    1.600439                 0.0         263.001751
# min       48.000000    1.000000              2770.0           0.000000
# 25%       82.000000    5.000000              2770.0         511.000000
# 50%       93.000000    6.000000              2770.0         604.000000
# 75%      100.000000    6.000000              2770.0         658.750000
# max      100.000000    8.000000              2770.0         851.000000
#
#        Max_Sea_Level_PressurehPa  Mean_Sea_Level_PressurehPa  Min_Dew_PointC  \
# count                 100.000000                  100.000000      100.000000
# mean                 1015.830000                 1012.640000        0.510000
# std                     7.535847                    7.723139        6.280473
# ...

# %%
sales_mean = df['NumberOfSales'].mean()

# %%
df['sales_nrmlz'] = df.apply(lambda x: (x['NumberOfSales'] - sales_mean) / sales_mean, axis=1)

# %%
df.head()
# Out:
#    Max_Humidity  CloudCover  Region_PopulationK  NumberOfCustomers  \
# 0           100         8.0                2770                495
# 1            87         8.0                2770                608
# 2            81         8.0                2770                665
# 3            80         6.0                2770                630
# 4            93         6.0                2770                  0
#
#    Max_Sea_Level_PressurehPa  Mean_Sea_Level_PressurehPa  Min_Dew_PointC  \
# 0                       1032                        1030              -2
# 1                       1030                        1027              -2
# 2                       1026                        1024              -3
# 3                       1027                        1024              -6
# 4                       1025                        1023              -6
#
#    NumberOfSales  Max_TemperatureC  Min_Sea_Level_PressurehPa     ...       \
# ...
