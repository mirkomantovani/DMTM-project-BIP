# %% [markdown]
# # Data exploration - Measure of Spread
#
# Analysis of the data spread.

# %%
from dataset_features import numerical, categorical

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":20,"axes.titlesize":30,"axes.labelsize":30})  

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./dataset/train.csv')

# Use only numerical attributes
df = df[numerical]
df.head()
# Out:
#    Min_Dew_PointC  Mean_TemperatureC  Mean_Wind_SpeedKm_h  Mean_VisibilityKm  \
# 0              -2                  1                   16               11.0
# 1              -2                  3                   10               13.0
# 2              -3                  3                   10               11.0
# 3              -6                  3                   10               15.0
# 4              -6                  1                    5               12.0
#
#    WindDirDegrees  Max_Wind_SpeedKm_h  NumberOfSales  Mean_Dew_PointC  \
# 0              23                  21           5676               -1
# 1              56                  16           8111               -1
# 2              22                  23           8300               -1
# 3             108                  19           7154               -4
# 4              46                  16              0               -3
#
#    Mean_Sea_Level_PressurehPa  Region_PopulationK        ...          \
# 0                        1030                2770        ...
# 1                        1027                2770        ...
# 2                        1024                2770        ...
# 3                        1024                2770        ...
# 4                        1023                2770        ...
#
#    Region_AreaKM2  Max_Gust_SpeedKm_h  Precipitationmm  Min_Humidity  \
# 0            9643                 NaN              0.0            70
# 1            9643                 NaN              0.0            58
# 2            9643                 NaN              0.0            55
# 3            9643                 NaN              0.0            25
# 4            9643                 NaN              0.0            48
#
#    Max_VisibilityKm  Min_VisibilitykM  Max_Humidity  Min_TemperatureC  \
# 0              19.0               6.0           100                 1
# 1              23.0              10.0            87                 1
# 2              31.0               8.0            81                 2
# 3              31.0              10.0            80                -1
# 4              31.0               5.0            93                -5
#
#    Region_GDP  NumberOfCustomers
# 0       17130                495
# 1       17130                608
# 2       17130                665
# 3       17130                630
# 4       17130                  0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Min, Range, Max

# %%
min_range_max = pd.DataFrame({
        'min': df.min(),
        'range': df.max() - df.min(),
        'max': df.max()
    })

min_range_max[['min', 'range', 'max']]
# Out:
#                                min     range       max
# Min_Dew_PointC               -18.0     36.00     18.00
# Mean_TemperatureC            -13.0     43.00     30.00
# Mean_Wind_SpeedKm_h            2.0     51.00     53.00
# Mean_VisibilityKm              0.0     31.00     31.00
# WindDirDegrees                -1.0    361.00    360.00
# Max_Wind_SpeedKm_h             3.0     98.00    101.00
# NumberOfSales                  0.0  26641.00  26641.00
# Mean_Dew_PointC              -15.0     35.00     20.00
# Mean_Sea_Level_PressurehPa   974.0     66.00   1040.00
# Region_PopulationK           816.0   7330.00   8146.00
# Min_Sea_Level_PressurehPa    970.0     68.00   1038.00
# CloudCover                     0.0      8.00      8.00
# Max_TemperatureC             -11.0     48.00     37.00
# NearestCompetitor             47.0  85023.00  85070.00
# Max_Sea_Level_PressurehPa    976.0     67.00   1043.00
# Mean_Humidity                 30.0     70.00    100.00
# Max_Dew_PointC               -14.0     37.00     23.00
# Region_AreaKM2               344.0  31877.00  32221.00
# Max_Gust_SpeedKm_h            21.0     85.00    106.00
# Precipitationmm                0.0     58.93     58.93
# Min_Humidity                  10.0     90.00    100.00
# Max_VisibilityKm               0.0     31.00     31.00
# Min_VisibilitykM               0.0     31.00     31.00
# Max_Humidity                  44.0     56.00    100.00
# Min_TemperatureC             -15.0     39.00     24.00
# Region_GDP                  9893.0  14038.00  23931.00
# NumberOfCustomers              0.0   2206.00   2206.00

# %% [markdown]
# ### Numerical attributes variance

# %%
df.var(axis=0)
# Out:
# Min_Dew_PointC                3.491743e+01
# Mean_TemperatureC             4.957803e+01
# Mean_Wind_SpeedKm_h           3.353604e+01
# Mean_VisibilityKm             2.478432e+01
# WindDirDegrees                1.034863e+04
# Max_Wind_SpeedKm_h            7.613053e+01
# NumberOfSales                 7.450882e+06
# Mean_Dew_PointC               3.459238e+01
# Mean_Sea_Level_PressurehPa    6.825276e+01
# Region_PopulationK            7.933909e+06
# Min_Sea_Level_PressurehPa     7.567671e+01
# CloudCover                    2.942175e+00
# Max_TemperatureC              6.717925e+01
# NearestCompetitor             1.331187e+08
# Max_Sea_Level_PressurehPa     6.377097e+01
# Mean_Humidity                 1.674368e+02
# Max_Dew_PointC                3.585976e+01
# Region_AreaKM2                8.355226e+07
# Max_Gust_SpeedKm_h            1.631170e+02
# Precipitationmm               6.924414e+00
# Min_Humidity                  3.718736e+02
# Max_VisibilityKm              8.408347e+01
# Min_VisibilitykM              2.400584e+01
# Max_Humidity                  5.802462e+01
# Min_TemperatureC              3.985388e+01
# Region_GDP                    7.592369e+06
# NumberOfCustomers             3.454286e+04
# dtype: float64

# %%
'Min variance attribute', df.var().idxmin(), df.var().min()
# Out:
# ('Min variance attribute', 'CloudCover', 2.9421751394678517)

# %%
'Max variance attribute', df.var().idxmax(), df.var().max()
# Out:
# ('Max variance attribute', 'NearestCompetitor', 133118695.05287102)

# %% [markdown]
# ### Variance bar plots
#
# All the attributes

# %%
df.var(axis=0).plot(kind='bar')

# %% [markdown]
# Excluding __NearestCompetitor, Region_AreaKM2__

# %%
df1 = df.var(axis=0).drop(['NearestCompetitor', 'Region_AreaKM2'])
df1.plot(kind='bar')

# %% [markdown]
# Excluding *NearestCompetitor*, __Region_PopulationK, NumberOfSales, Region_GDP,__ *Region_AreaKM2*

# %%
df2 = df.var(axis=0).drop(['NearestCompetitor', 'Region_PopulationK', 'NumberOfSales', 'Region_GDP', 'Region_AreaKM2'])
df2.plot(kind='bar')

# %% [markdown]
# Excluding *NearestCompetitor, Region_PopulationK, NumberOfSales, __WindDirDegrees, NumberOfCustomers__, Region_GDP, Region_AreaKM2*

# %%
df2 = df.var(axis=0).drop(['NearestCompetitor', 'Region_PopulationK', 'NumberOfSales', 'WindDirDegrees', 'NumberOfCustomers', 'Region_GDP', 'Region_AreaKM2'])
df2.plot(kind='bar')

# %% [markdown]
# The above vertical bar plot excludes the 7 highest variance attributes and shows the variances of the remaining attributes.

# %% [markdown]
# ## Variance bar plot after normalization

# %%
df.shape
# Out:
# (523021, 27)

# %%
df.describe()
# Out:
#        Min_Dew_PointC  Mean_TemperatureC  Mean_Wind_SpeedKm_h  \
# count   523021.000000      523021.000000        523021.000000
# mean         3.737584          10.273205            11.724961
# std          5.909098           7.041167             5.791031
# min        -18.000000         -13.000000             2.000000
# 25%         -1.000000           4.000000             8.000000
# 50%          4.000000          11.000000            11.000000
# 75%          8.000000          16.000000            14.000000
# max         18.000000          30.000000            53.000000
#
#        Mean_VisibilityKm  WindDirDegrees  Max_Wind_SpeedKm_h  NumberOfSales  \
# count      511683.000000   523021.000000       523021.000000  523021.000000
# mean           12.151025      170.458096           22.223437    4057.377536
# std             4.978385      101.728193            8.725281    2729.630381
# min             0.000000       -1.000000            3.000000       0.000000
# 25%            10.000000       75.000000           14.000000    2573.000000
# 50%            11.000000      191.000000           21.000000    4020.000000
# 75%            14.000000      250.000000           26.000000    5538.000000
# max            31.000000      360.000000          101.000000   26641.000000
#
#        Mean_Dew_PointC  Mean_Sea_Level_PressurehPa  Region_PopulationK  \
# count    523021.000000               523021.000000       523021.000000
# mean          6.229677                 1015.002422         3861.519300
# std           5.881529                    8.261523         2816.719484
# min         -15.000000                  974.000000          816.000000
# 25%           2.000000                 1010.000000         1293.000000
# 50%           7.000000                 1015.000000         2770.000000
# 75%          11.000000                 1020.000000         5727.000000
# max          20.000000                 1040.000000         8146.000000
#
#              ...          Region_AreaKM2  Max_Gust_SpeedKm_h  Precipitationmm  \
# count        ...           523021.000000       113074.000000    523021.000000
# mean         ...            12381.265718           47.980782         0.808278
# std          ...             9140.692427           12.771727         2.631428
# min          ...              344.000000           21.000000         0.000000
# 25%          ...             7215.000000           39.000000         0.000000
# 50%          ...             9643.000000           47.000000         0.000000
# 75%          ...            15566.000000           55.000000         0.250000
# max          ...            32221.000000          106.000000        58.930000
#
#         Min_Humidity  Max_VisibilityKm  Min_VisibilitykM   Max_Humidity  \
# count  523021.000000     511683.000000     511683.000000  523021.000000
# mean       51.375624         23.560275          7.223408      93.523316
# std        19.284023          9.169704          4.899575       7.617389
# min        10.000000          0.000000          0.000000      44.000000
# 25%        36.000000         11.000000          3.000000      90.000000
# 50%        51.000000         31.000000          8.000000      94.000000
# 75%        66.000000         31.000000         10.000000     100.000000
# max       100.000000         31.000000         31.000000     100.000000
#
#        Min_TemperatureC     Region_GDP  NumberOfCustomers
# count     523021.000000  523021.000000      523021.000000
# mean           6.202315   14050.547848         259.325073
# std            6.312993    2755.425404         185.857102
# min          -15.000000    9893.000000           0.000000
# 25%            1.000000   11849.000000         166.000000
# 50%            7.000000   15017.000000         251.000000
# 75%           11.000000   15931.000000         345.000000
# max           24.000000   23931.000000        2206.000000
#
# [8 rows x 27 columns]

# %%
df_norm = pd.DataFrame()

for column in numerical:
    df_norm[column] = (df[column] - df[column].mean()) / (df[column].max() - df[column].min())

df_norm.head()
# Out:
#    Min_Dew_PointC  Mean_TemperatureC  Mean_Wind_SpeedKm_h  Mean_VisibilityKm  \
# 0       -0.159377          -0.215656             0.083824          -0.037130
# 1       -0.159377          -0.169144            -0.033823           0.027386
# 2       -0.187155          -0.169144            -0.033823          -0.037130
# 3       -0.270488          -0.169144            -0.033823           0.091902
# 4       -0.270488          -0.215656            -0.131862          -0.004872
#
#    WindDirDegrees  Max_Wind_SpeedKm_h  NumberOfSales  Mean_Dew_PointC  \
# 0       -0.408471           -0.012484       0.060757        -0.206562
# 1       -0.317058           -0.063504       0.152157        -0.206562
# 2       -0.411241            0.007924       0.159252        -0.206562
# 3       -0.173014           -0.032892       0.116235        -0.292276
# 4       -0.344759           -0.063504      -0.152298        -0.263705
#
#    Mean_Sea_Level_PressurehPa  Region_PopulationK        ...          \
# 0                    0.227236           -0.148911        ...
# 1                    0.181781           -0.148911        ...
# 2                    0.136327           -0.148911        ...
# 3                    0.136327           -0.148911        ...
# 4                    0.121175           -0.148911        ...
#
#    Region_AreaKM2  Max_Gust_SpeedKm_h  Precipitationmm  Min_Humidity  \
# 0       -0.085901                 NaN        -0.013716      0.206938
# 1       -0.085901                 NaN        -0.013716      0.073604
# 2       -0.085901                 NaN        -0.013716      0.040271
# 3       -0.085901                 NaN        -0.013716     -0.293062
# 4       -0.085901                 NaN        -0.013716     -0.037507
#
#    Max_VisibilityKm  Min_VisibilitykM  Max_Humidity  Min_TemperatureC  \
# 0         -0.147106         -0.039465      0.115655         -0.133393
# 1         -0.018073          0.089567     -0.116488         -0.133393
# 2          0.239991          0.025051     -0.223631         -0.107752
# 3          0.239991          0.089567     -0.241488         -0.184675
# 4          0.239991         -0.071723     -0.009345         -0.287239
#
#    Region_GDP  NumberOfCustomers
# 0    0.219365           0.106834
# 1    0.219365           0.158058
# 2    0.219365           0.183896
# 3    0.219365           0.168030
# 4    0.219365          -0.117554
#
# [5 rows x 27 columns]

# %%
df_norm.var(axis=0).plot(kind='bar')

# %% [markdown]
# # Box plots

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
sns.boxplot(x="NumberOfSales", y="NumberOfCustomers", data=df[numerical_variables_with_class])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6529817b44fe> in <module>()
#       1 sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
# ----> 2 sns.boxplot(x="NumberOfSales", y="NumberOfCustomers", data=df[numerical_variables_with_class])
#
# NameError: name 'numerical_variables_with_class' is not defined
