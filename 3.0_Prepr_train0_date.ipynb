# %% [markdown]
# # Data preprocessing: Date extraction
#
# **NOTEBOOK GOAL**: Extract attributes: Day, Month and Year from the Date attribute
#
# **DATASET TRANSFORMATION**: `(train|test).csv` >> `preprocessed0_date_(train|test).csv`

# %%
# reoder variables to work on train or test dataset
work_on = 'test'
#work_on = 'train'

# %%
from import_man import *

from datetime import datetime

# %%
df = pd.read_csv('./dataset/' + work_on + '.csv')
df.head()
# Out:
#    StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 0     1000  01/03/2018          0       1              0  Hyper Market
# 1     1000  02/03/2018          0       1              0  Hyper Market
# 2     1000  03/03/2018          0       1              0  Hyper Market
# 3     1000  04/03/2018          0       0              0  Hyper Market
# 4     1000  05/03/2018          0       1              1  Hyper Market
#
#   AssortmentType  NearestCompetitor  Region  Region_AreaKM2       ...        \
# 0        General                326       7            9643       ...
# 1        General                326       7            9643       ...
# 2        General                326       7            9643       ...
# 3        General                326       7            9643       ...
# 4        General                326       7            9643       ...
#
#    Mean_TemperatureC  Mean_VisibilityKm  Mean_Wind_SpeedKm_h Min_Dew_PointC  \
# ...

# %%
df['D_Day'] =  df['Date'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').day)
df['D_DayOfYear'] =  df['Date'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').timetuple().tm_yday)

# %%
df['D_Month'] =  df['Date'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').month)

# %%
df['D_Year'] =  df['Date'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').year)

# %%
df['D_DayOfweek'] =  df['Date'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').weekday())

# %%
df.head(10)
# Out:
#    StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 0     1000  01/03/2018          0       1              0  Hyper Market
# 1     1000  02/03/2018          0       1              0  Hyper Market
# 2     1000  03/03/2018          0       1              0  Hyper Market
# 3     1000  04/03/2018          0       0              0  Hyper Market
# 4     1000  05/03/2018          0       1              1  Hyper Market
# 5     1000  06/03/2018          0       1              1  Hyper Market
# 6     1000  07/03/2018          0       1              1  Hyper Market
# 7     1000  08/03/2018          0       1              1  Hyper Market
# 8     1000  09/03/2018          0       1              1  Hyper Market
# 9     1000  10/03/2018          0       1              0  Hyper Market
#
#   AssortmentType  NearestCompetitor  Region  Region_AreaKM2     ...       \
# 0        General                326       7            9643     ...
# ...

# %%
print("ATTRIBUTES LIST:")
pprint(list(df.columns))

print("\n\nSORTED ATTRIBUTES LIST:")
pprint(sorted(list(df.columns)))
# Out:
# ATTRIBUTES LIST:
# ['StoreID',
#  'Date',
#  'IsHoliday',
#  'IsOpen',
#  'HasPromotions',
#  'StoreType',
#  'AssortmentType',
#  'NearestCompetitor',
#  'Region',
#  'NumberOfCustomers',
#  'NumberOfSales',
#  'Region_AreaKM2',
#  'Region_GDP',
#  'Region_PopulationK',
#  'CloudCover',
#  'Events',
#  'Max_Dew_PointC',
#  'Max_Gust_SpeedKm_h',
#  'Max_Humidity',
#  'Max_Sea_Level_PressurehPa',
#  'Max_TemperatureC',
#  'Max_VisibilityKm',
#  'Max_Wind_SpeedKm_h',
#  'Mean_Dew_PointC',
#  'Mean_Humidity',
#  'Mean_Sea_Level_PressurehPa',
#  'Mean_TemperatureC',
#  'Mean_VisibilityKm',
#  'Mean_Wind_SpeedKm_h',
#  'Min_Dew_PointC',
#  'Min_Humidity',
#  'Min_Sea_Level_PressurehPa',
#  'Min_TemperatureC',
#  'Min_VisibilitykM',
#  'Precipitationmm',
#  'WindDirDegrees',
#  'D_Day',
#  'D_DayOfYear',
#  'D_Month',
#  'D_Year',
#  'D_DayOfweek']
#
#
# SORTED ATTRIBUTES LIST:
# ['AssortmentType',
#  'CloudCover',
#  'D_Day',
#  'D_DayOfYear',
#  'D_DayOfweek',
#  'D_Month',
#  'D_Year',
# ...

# %% [markdown]
# ### Write to file

# %%
# save the dataset
df.to_csv('./dataset/preprocessed0_date_' + work_on + '.csv', index=False)
